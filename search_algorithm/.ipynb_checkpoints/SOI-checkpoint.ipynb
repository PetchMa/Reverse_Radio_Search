# %% [markdown]
# # Picking Signals of Interests.
# Here we want to find signals that appear interesting from the untouched search. We take an energy detection candidates and use them as SOI's

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from blimpy import Waterfall
import os

di_list = pd.read_csv("test_file_directory.csv")['names'].to_list()
data_directory_list = pd.read_csv('../data_generator/test_directories.csv')
data_directory_list
# Out:
#    Unnamed: 0                                     HIP104887-1850  \
# 0           0  /mnt_blpd9/datax/dl/GBT_57691_04379_HIP104887_...
# 1           1  /mnt_blpd9/datax/dl/GBT_57691_04732_HIP103749_...
# 2           2  /mnt_blpd9/datax/dl/GBT_57691_05084_HIP104887_...
# 3           3  /mnt_blpd9/datax/dl/GBT_57691_05425_HIP103782_...
# 4           4  /mnt_blpd9/datax/dl/GBT_57691_05766_HIP104887_...
# 5           5  /mnt_blpd9/datax/dl/GBT_57691_06113_HIP103793_...
#
#                                        HIP87579-1008
# 0  /mnt_blpd7/datax/dl/GBT_57907_34727_HIP87579_f...
# 1  /mnt_blpd7/datax/dl/GBT_57907_35062_HIP87059_f...
# 2  /mnt_blpd7/datax/dl/GBT_57907_35397_HIP87579_f...
# 3  /mnt_blpd7/datax/dl/GBT_57907_35736_HIP87225_f...
# 4  /mnt_blpd7/datax/dl/GBT_57907_36075_HIP87579_f...
# 5  /mnt_blpd7/datax/dl/GBT_57907_36414_HIP87278_f...

# %%
def find_directory(target, data):
    headers = data.columns.to_list()
    headers.pop(0)
    for key in headers:
        li = data[key].to_list()
        if key != "Unnamed: 0" or key != '':
            for el in li:
                if target in el:
                    return el
    return -1

# %%
from random import randint
WINDOW = 256*2.89e-6/2

SOI_data = []
SOI_info = {}
for directory in di_list:
    df = pd.read_pickle(directory+"/info_df.pkl")
    stats = df["statistic"].to_list()
    freqs = df['freqs']
    index = randint(0, len(freqs))
    SOI_freq = freqs[index]
    info = pd.read_pickle(directory+"/header.pkl")
    window = info['foff'] *256/2
    file_name = directory.split("/")[-1]
    file_directory = find_directory(file_name, data_directory_list)
    data = Waterfall(file_directory, f_start=SOI_freq+window, f_stop = SOI_freq-window).data
    SOI_data.append(data)
    SOI_info[file_name] = {"freq":SOI_freq, "start":SOI_freq+window,"end":SOI_freq-window,
                          "directory":file_directory, "stats":stats[index]}
# Out:
# {'GBT_57907_34727_HIP87579_fine': {'freq': 2317.0600175857544, 'start': 2317.0596599578857, 'end': 2317.060375213623, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_34727_HIP87579_fine.h5', 'stats': 6023.992540717432}, 'GBT_57907_35736_HIP87225_fine': {'freq': 2188.4362936019897, 'start': 2188.435935974121, 'end': 2188.4366512298584, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_35736_HIP87225_fine.h5', 'stats': 9289.438920671824}, 'GBT_57907_36075_HIP87579_fine': {'freq': 2196.5548038482666, 'start': 2196.554446220398, 'end': 2196.5551614761353, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_36075_HIP87579_fine.h5', 'stats': 2226.196336231094}, 'GBT_57907_35062_HIP87059_fine': {'freq': 1923.8925218582153, 'start': 1923.8921642303467, 'end': 1923.892879486084, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_35062_HIP87059_fine.h5', 'stats': 3516.258254879318}, 'GBT_57907_36414_HIP87278_fine': {'freq': 2197.1431016921997, 'start': 2197.142744064331, 'end': 2197.1434593200684, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_36414_HIP87278_fine.h5', 'stats': 6706.028819044686}, 'GBT_57907_35397_HIP87579_fine': {'freq': 2197.8672981262207, 'start': 2197.866940498352, 'end': 2197.8676557540894, 'directory': '/mnt_blpd7/datax/dl/GBT_57907_35397_HIP87579_fine.h5', 'stats': 6466.086839134555}, 'GBT_57691_05425_HIP103782_fine': {'freq': 1921.562933921814, 'start': 1921.5625762939453, 'end': 1921.5632915496826, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_05425_HIP103782_fine.h5', 'stats': 3029.84325372966}, 'GBT_57691_05766_HIP104887_fine': {'freq': 1921.1859941482544, 'start': 1921.1856365203857, 'end': 1921.186351776123, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_05766_HIP104887_fine.h5', 'stats': 3659.0316876415445}, 'GBT_57691_06113_HIP103793_fine': {'freq': 1921.6906070709229, 'start': 1921.6902494430542, 'end': 1921.6909646987915, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_06113_HIP103793_fine.h5', 'stats': 2436.5167116103853}, 'GBT_57691_04379_HIP104887_fine': {'freq': 1921.3072299957275, 'start': 1921.306872367859, 'end': 1921.3075876235962, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_04379_HIP104887_fine.h5', 'stats': 2631.6200113274626}, 'GBT_57691_04732_HIP103749_fine': {'freq': 1926.6813039779663, 'start': 1926.6809463500977, 'end': 1926.681661605835, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_04732_HIP103749_fine.h5', 'stats': 2441.253607101018}, 'GBT_57691_05084_HIP104887_fine': {'freq': 1921.8708515167236, 'start': 1921.870493888855, 'end': 1921.8712091445923, 'directory': '/mnt_blpd9/datax/dl/GBT_57691_05084_HIP104887_fine.h5', 'stats': 2683.2972061071778}}

# %%
import pickle

with open('SOI.pkl', 'wb') as handle:
    pickle.dump(SOI_info, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# %matplotlib inline
font_size = 50
plt.rcParams.update({'font.size': font_size})

f, ax = plt.subplots(4, 3, sharey=True, figsize=(30, 30), constrained_layout=True)

for j in range(4):
    for i in range(3):
        data = SOI_data[(j*3)+i]
        im = ax[j,i].imshow(data[:, 0,:], cmap='hot', interpolation='nearest', aspect="auto")
        if j == 3:
            ax[j,i].set_xlabel("Frequency [2.89 Hz]",  fontsize=font_size-10)  
        if i ==0:
            ax[j,i].set_ylabel("Time [18.7s]",  fontsize=font_size-5)  
                   
cbaxes = f.add_axes([1.04, 0.2, 0.015, 0.6]) 
cbar = f.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
f.text(1.11, 0.5, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size+10)

# plt.savefig("plots/SOI.pdf", format="pdf")
# Out:
# Text(1.11, 0.5, 'Power [normalized]')
