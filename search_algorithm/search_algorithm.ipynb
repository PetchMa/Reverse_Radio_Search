# %% [markdown]
# # Search Algorithm With Embedding

# %%
from blimpy import Waterfall
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# numexpr.utils   INFO     Note: NumExpr detected 40 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# numexpr.utils   INFO     NumExpr defaulting to 8 threads.
# 2022-12-20 14:40:41.574004: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# # Load Model

# %%
latent_dim = 5
time_samples = 16
freq_sample =  256
encoder_inputs = keras.Input(shape=(time_samples, freq_sample, 1))
x = layers.Conv2D(16, 3, activation="relu", strides=1, padding="same")(encoder_inputs)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x_shape = x.shape
x = layers.Flatten()(x)
x = layers.Dense(32, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(16, activation="relu")(x)
x = layers.BatchNormalization()(x)
z = layers.Dense(latent_dim, name="latent")(x)
encoder = keras.Model(encoder_inputs, z, name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(32, activation="relu")(latent_inputs)
x = layers.BatchNormalization()(x)
x = layers.Dense(x_shape[1]* x_shape[2]* x_shape[3], activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Reshape((x_shape[1], x_shape[2], x_shape[3]))(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(16, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="linear", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# 2022-12-20 14:40:44.626449: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-12-20 14:40:44.628639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-12-20 14:40:44.716069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:44.716638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:44.717173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:44.717688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:44.717732: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-12-20 14:40:44.820136: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-12-20 14:40:44.820205: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-12-20 14:40:44.891446: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-12-20 14:40:45.033827: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-12-20 14:40:45.167686: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-12-20 14:40:45.238074: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-12-20 14:40:45.293805: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-12-20 14:40:45.298600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-12-20 14:40:45.299292: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-20 14:40:45.303076: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-12-20 14:40:45.549172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:45.549469: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:45.549740: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:45.550004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: NVIDIA GeForce GTX TITAN X computeCapability: 5.2
# coreClock: 1.076GHz coreCount: 24 deviceMemorySize: 11.93GiB deviceMemoryBandwidth: 313.37GiB/s
# 2022-12-20 14:40:45.550067: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-12-20 14:40:45.550097: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-12-20 14:40:45.550121: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-12-20 14:40:45.550145: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-12-20 14:40:45.550169: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-12-20 14:40:45.550193: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-12-20 14:40:45.550216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-12-20 14:40:45.550240: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-12-20 14:40:45.552242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2022-12-20 14:40:45.552295: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-12-20 14:40:46.975860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-20 14:40:46.975939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2022-12-20 14:40:46.975968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N Y N N
# 2022-12-20 14:40:46.975977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   Y N N N
# 2022-12-20 14:40:46.975985: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   N N N Y
# 2022-12-20 14:40:46.975994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   N N Y N
# 2022-12-20 14:40:46.977979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 11278 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:02:00.0, compute capability: 5.2)
# 2022-12-20 14:40:46.978902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 11278 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:03:00.0, compute capability: 5.2)
# 2022-12-20 14:40:46.979820: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 11278 MB memory) -> physical GPU (device: 2, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:83:00.0, compute capability: 5.2)
# 2022-12-20 14:40:46.980668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 11278 MB memory) -> physical GPU (device: 3, name: NVIDIA GeForce GTX TITAN X, pci bus id: 0000:84:00.0, compute capability: 5.2)
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 16, 256, 1)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 256, 16)       160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 128, 16)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 128, 16)       64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 128, 32)       4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 64, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 32, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 32, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 8, 32)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 8, 32)         128
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16)                64
# _________________________________________________________________
# latent (Dense)               (None, 5)                 85
# =================================================================
# Total params: 165,029
# Trainable params: 164,645
# Non-trainable params: 384
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 5)]               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                192
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              135168
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4096)              16384
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 8, 32)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 32, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 32, 32)        128
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 64, 32)        0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 64, 32)        128
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 32, 128, 32)       9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 128, 32)       0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 128, 32)       128
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 32, 256, 16)       4624
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 256, 16)       0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 256, 16)       64
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 16, 256, 1)        145
# =================================================================
# Total params: 194,209
# Trainable params: 185,665
# Non-trainable params: 8,544
# _________________________________________________________________

# %%
from AE import AE

autoencoder = AE(encoder, decoder)
autoencoder.load_weights("../autoencoder/models/full-weights-"+'12-16-2022-11-47-35')

# %% [markdown]
# # Load Data

# %%
from tqdm import tqdm
def normalize(data):
    epsilon = 1
    min_val = data.min()
    data = data - min_val + epsilon
    new_data = np.log(data)
    min_val = data.min()
    max_val = data.max()
    final_data = (data - min_val) / (max_val - min_val)
    return final_data
    
def normalize_data(data):
    new_data = np.zeros((data.shape[-1]//256, 16, 256,1))
    for i in tqdm(range(new_data.shape[0])):
        new_data[i,:,:, 0] = normalize(data[:,0, i*256:(i+1)*256])
    return new_data

def find_directory(target, data):
    headers = data.columns.to_list()
    headers.pop(0)
    for key in headers:
        li = data[key].to_list()
        if key != "Unnamed: 0" or key != '':
            for el in li:
                if target in el:
                    return el
    return -1

# %%
import pickle

df = pd.read_csv("../data_generator/test_directories.csv")

with open('SOI.pkl', 'rb') as handle:
    SOI = pickle.load(handle)

target1 = SOI["GBT_57907_34727_HIP87579_fine"]
target1_data = Waterfall("../../../../../../../"+target1["directory"], 
                 f_start = target1["start"], f_stop=target1["end"]).data


data = Waterfall("../../../../../../../"+target1["directory"], max_load=False).data
preprocessed_data = normalize_data(data)
# Out:
# 100%|██████████████████████████████| 1404928/1404928 [01:27<00:00, 16104.64it/s]

# %%
print(data.shape)
# Out:
# (16, 1, 359661568)

# %% [markdown]
# # Feature Extractor

# %%
key_features = autoencoder.encoder.predict(preprocessed_data, batch_size=1024)
print(key_features.shape)
# Out:
# 2022-12-20 14:43:11.390132: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 23018340352 exceeds 10% of free system memory.
# 2022-12-20 14:43:29.064124: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-12-20 14:43:29.083228: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2200070000 Hz
# 2022-12-20 14:43:29.312103: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-12-20 14:43:29.529746: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# (1404928, 5)

# %% [markdown]
# # Frequency Embedding

# %%
print(data.shape[-1]//256)
data = np.zeros((1243088, 4))
# Out:
# 1404928

# %%
def getFrequencyEncoding(seq_len, d, n=10000):
    P = np.zeros((seq_len, d))
    for k in range(seq_len):
        for i in np.arange(int(d/2)):
            denominator = np.power(n, 2*i/d)
            P[k, 2*i] = np.sin(k/denominator)
            P[k, 2*i+1] = np.cos(k/denominator)
    return P
 
F = getFrequencyEncoding(seq_len=1009, d=5, n=100000)

print(F.shape)

for i in tqdm(range(F.shape[0])):
    for k in range(112):
        key_features[(i*112)+k,:] += F[i,:]
# Out:
# (1009, 5)
# 100%|█████████████████████████████████████| 1009/1009 [00:00<00:00, 2630.52it/s]

# %% [markdown]
# # Search Algorithm

# %%
eps = 0
SOI_feature = autoencoder.encoder.predict(normalize_data(target1_data), batch_size=1)
print(SOI_feature.shape)
SOI_feature = np.swapaxes(SOI_feature, 0, -1)
SOI_norm = np.linalg.norm(SOI_feature)
data_norm = np.linalg.norm(key_features, axis = 1) + eps
print(key_features.shape)
similarity = np.matmul(key_features, SOI_feature)[:,0]
similarity = np.divide(similarity, data_norm)/SOI_norm
print(similarity)
best_index = (-similarity).argsort()[:-1000]
print(similarity.max())
print(best_index)
# Out:
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1141.62it/s]
# (1, 5)
# (1404928, 5)
# [0.9297227 0.9224503 0.9515172 ... 0.9304319 0.9255808 0.9651847]
# 0.9999998
# [1176584 1190706 1172028 ...  441325  444969  442161]

# %%
best_index[0]
# Out:
# 1176584

# %%
# %matplotlib inline

plt.figure()
plt.imshow(normalize_data(target1_data)[0,:,:,0], cmap='hot', interpolation='nearest', aspect=10)

for i in range(5):
    plt.figure()
    plt.imshow(preprocessed_data[best_index[i],:, :], cmap='hot', interpolation='nearest', aspect=10)
# Out:
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 2146.52it/s]

# %% [markdown]
# ### get some header information

# %%
header = Waterfall("../../../../../../../"+target1["directory"], 
                 load_data = False).header
end = header['fch1']
foff = header['foff']
nchan = header['nchans']
start = end+nchan*foff
print(start, end)
intervals = (end-start)/similarity.shape[0]
print(intervals)
print( target1["start"])
# Out:
# 1797.94921875 2802.83203125
# 0.0007152557373046875
# 1961.2728595733643

# %%
font_size = 25
plt.rcParams.update({'font.size': font_size})
f, ax = plt.subplots(nrows=5, ncols=5, figsize=(15,15))

count = 0
row_count = 0
for row in ax:
    col_count = 0 
    for col in row:
        im = col.imshow(preprocessed_data[best_index[count],:, :], cmap='hot', interpolation='nearest', aspect=10)
        freq = end-best_index[count]*intervals
        col.set_xlabel(str(round(freq, 2))+" [MHz]",  fontsize=font_size-5)  
        col.get_xaxis().set_ticks([])
        col.get_yaxis().set_ticks([])
        if col_count ==0 and row_count == 2:
            col.set_ylabel("Time",  fontsize=font_size*2)  
        col_count+=1
        count += 1 
    row_count += 1
    
f.text(0.5, 0.07, 'Frequency', ha='center', va='center', rotation=0, 
       fontsize=font_size*2)


cbaxes = f.add_axes([0.95, 0.2, 0.015, 0.6]) 
cbar = f.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
f.text(1.06, 0.5, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size+10)

plt.show()

# %% [markdown]
# # Check Distribution

# %%
1176584*intervals+end
# Out:
# 3644.3904876708984

# %%
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(15,8))
hist, bins = np.histogram(end-best_index[:50000]*intervals, bins=100)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width, label="Hit Bins")
key = 0
for i in range(len(center)):
    if center[i] > target1["start"]:
        key = i
        break
plt.bar(center[key-1], hist[key-1], align='center', width=width, label="True SOI bin")
plt.ylabel("Number of Similar Hits")
plt.xlabel("Frequency [MHz]")
plt.grid()
plt.legend()

# %% [markdown]
# # Merge Plots Together

# %%
fig = plt.figure(figsize=(15, 10), layout="constrained")
spec = fig.add_gridspec(6, 5)

main = fig.add_subplot(spec[0, 0:2])
im = main.imshow(normalize_data(target1_data)[0,:,:,0], cmap='hot', interpolation='nearest', aspect=10)
main.get_xaxis().set_ticks([])
main.get_yaxis().set_ticks([])
main.set_xlabel("True Target - "+str(round(target1["start"], 2))+" MHz")

ax0 = fig.add_subplot(spec[0, 3:])
im = ax0.imshow(preprocessed_data[best_index[0],:, :], cmap='hot', interpolation='nearest', aspect=10)
ax0.get_xaxis().set_ticks([])
ax0.get_yaxis().set_ticks([])
freq = end-best_index[0]*intervals
ax0.set_xlabel("Best Match: "+str(round(freq, 2))+" [MHz]",  fontsize=font_size-5)          
count = 1
for i in range(1,3):
    for j in range(5):
        ax = fig.add_subplot(spec[i, j])
        im = ax.imshow(preprocessed_data[best_index[count],:, :], cmap='hot', interpolation='nearest', aspect=10)
        freq = end-best_index[count]*intervals
        ax.get_xaxis().set_ticks([])
        ax.get_yaxis().set_ticks([])
        ax.set_xlabel(str(round(freq, 2))+" [MHz]",  fontsize=font_size-5)  
        count +=1

fig.text(0.55, 0.40, '(a)', ha='center', va='center', rotation=0, fontsize=font_size)
# histogram
ax1 = fig.add_subplot(spec[4:, :])  
hist, bins = np.histogram(end-best_index[:20000]*intervals, bins=100)
width = 0.7 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width, label="Hit Bins")
key = 0
for i in range(len(center)):
    if center[i] > target1["start"]:
        key = i
        break

ax1.bar(center[key-1], hist[key-1], align='center', width=width, label="True SOI bin")
ax1.legend()        
ax1.grid()     
ax1.set_xlabel("Frequency [MHz]")
ax1.set_ylabel("Num of Similar Hits")

cbaxes = fig.add_axes([1.02, 0.5, 0.02, 0.4]) 
cbar = fig.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
fig.text(1.13, 0.70, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size)

fig.text(0.55, -0.05, '(b)', ha='center', va='center', rotation=0, 
       fontsize=font_size)


target_name = target1['directory'].split("/")[-1].split('.')[0]
plt.savefig("plots/full_algo/full_algo-"+target_name+".pdf", format="pdf")
# Out:
# 100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 1871.62it/s]
