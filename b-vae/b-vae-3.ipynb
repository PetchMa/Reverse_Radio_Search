# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import silhouette_score
# Out:
# 2023-05-20 17:13:04.830900: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load Data

# %%
import os

directory = os.fsencode( "../../../../../datax/scratch/pma/reverse_search/train/")
count = 0
data = []
for folder in os.listdir(directory):
    print(folder)
    for subfolder in os.listdir(directory+folder):
        back = os.fsencode( "/")
        for file in os.listdir(directory+folder+back+subfolder):
            file_directory = str(os.path.join(directory+folder+back+subfolder, file)).replace('b', '').replace("'","")
            if 'filtered.npy' in file_directory:
                data.append(np.load(str(file_directory)))
                count += 1
# Out:
# b'HIP44295-23'
# b'HIP63503-523'
# b'AND_XI-2274'
# b'HIP36393-1253'
# b'HIP48477-589'

# %%
import numpy as np
data = np.vstack(data)
print(data.shape)

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 10})
plt.figure(figsize=(10,5))
plt.title("Example")
plt.xlabel("Frequency")
plt.ylabel("Time")
plt.imshow(data[1000, :, :], cmap='hot', aspect=5)
# Out:
# (666733, 16, 256)

# %%
from tqdm import tqdm

def normalize(data):
    epsilon = 1
    min_val = data.min()
    data = data - min_val + epsilon
    new_data = np.log(data)
    min_val = data.min()
    max_val = data.max()
    final_data = (data - min_val) / (max_val - min_val)
    return final_data
    
def normalize_data(data):
    for i in tqdm(range(data.shape[0])):
        data[i,:,:] = normalize(data[i,:,:])
    return data

data = np.expand_dims(normalize_data(data), axis = -1)
print(data[0,:,:].max(), data[0,:,:].min())
# Out:
# 100%|██████████████████████████████| 666733/666733 [01:00<00:00, 10991.47it/s]
# 1.0 0.0

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 10})
plt.figure(figsize=(10,5))
plt.title("Example")
plt.xlabel("Frequency")
plt.ylabel("Time")
plt.imshow(data[1000, :, :], cmap='hot', aspect=5)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, data, test_size=0.33, random_state=42)

# %%
ind = np.random.randint(0, X_train.shape[0], size=(10, 10))
font_size = 25
plt.rcParams.update({'font.size': font_size})

f, ax = plt.subplots(4, 10, sharey=True, figsize=(30, 10), constrained_layout=True)

for j in range(10):
    for i in range(4):
        inde = ind[i, j]
        im = ax[i,j].imshow(X_train[inde,:,:,0], cmap='hot', interpolation='nearest', aspect="auto")
        if i == 3:
            ax[i,j].set_xlabel("Frequency [2.89 Hz]",  fontsize=font_size-10)  
        if j ==0:
            ax[i,j].set_ylabel("Time [18.7s]",  fontsize=font_size-5)  
                  
cbaxes = f.add_axes([1.01, 0.2, 0.015, 0.6]) 
cbar = f.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
f.text(1.06, 0.5, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size+10)

plt.savefig("plots/training_examples.pdf", format="pdf")

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta = 8
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(
            name="kl_loss"
        )
        self.kl_additional = tf.keras.losses.KLDivergence()
    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
        ]
    def gaussanity_loss(self, data, base):
        return self.kl_additional(data, base)
    
    def train_step(self, data_in):
        data = data_in
        print(data.shape)
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            
            
            total_loss = reconstruction_loss + self.beta * kl_loss
        
        mse_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.mse(data, reconstruction), axis=(1, 2)
                )
            )
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_tracker.update_state(mse_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
        }
    def test_step(self, data_in):
        data, _ = data_in
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
            )
        )
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))

        total_loss = reconstruction_loss + self.beta * kl_loss 
        
        mse_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.mse(data, reconstruction), axis=(1, 2)
                )
            )
        self.total_loss_tracker.update_state(total_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        self.reconstruction_loss_tracker.update_state(mse_loss)
        return {
            "test_loss": self.total_loss_tracker.result(),
            "test_kl_loss": self.kl_loss_tracker.result(),
            "test_reconstruction_loss": self.reconstruction_loss_tracker.result()
        }

# %% [markdown]
# # Encoder Model

# %%
latent_dim = 8
time_samples = X_train.shape[1]
freq_sample =  X_train.shape[2]
encoder_inputs = keras.Input(shape=(time_samples, freq_sample, 1))
x = layers.Conv2D(16, 3, activation="relu", strides=1, padding="same")(encoder_inputs)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
x = layers.MaxPool2D(pool_size=(1, 2))(x)
x = layers.BatchNormalization()(x)
x_shape = x.shape
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(64, activation="relu")(x)
x = layers.BatchNormalization()(x)


z_mean = layers.Dense(64, activation="relu")(x)
z_mean = layers.BatchNormalization()(z_mean)
z_mean = layers.Dense(latent_dim, name="z_mean")(z_mean)

z_log_var = layers.Dense(64, activation="relu")(x)
z_log_var = layers.BatchNormalization()(z_log_var)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(z_log_var)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 16, 256, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 16, 256, 16)  160         ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 128, 16)  0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 128, 16)  64         ['max_pooling2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 16, 128, 32)  4640        ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 64, 32)  0           ['conv2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 64, 32)  128         ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 16, 64, 32)   9248        ['batch_normalization_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 32, 32)  0           ['conv2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 32, 32)  128         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 16, 32, 32)   9248        ['batch_normalization_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)  0           ['conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 32)  128         ['max_pooling2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 32)   9248        ['batch_normalization_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 8, 32)   0           ['conv2d_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 8, 32)   128         ['max_pooling2d_4[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 4096)         0           ['batch_normalization_4[0][0]']
#
#  dense (Dense)                  (None, 128)          524416      ['flatten[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 128)         512         ['dense[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 64)           8256        ['batch_normalization_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64)          256         ['dense_1[0][0]']
# 2023-05-20 17:14:24.778430: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-20 17:14:26.034316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14233 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-05-20 17:14:26.035126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14233 MB memory:  -> device: 1, name: NVIDIA RTX A4000, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2023-05-20 17:14:26.035655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 14233 MB memory:  -> device: 2, name: NVIDIA RTX A4000, pci bus id: 0000:a1:00.0, compute capability: 8.6
# 2023-05-20 17:14:26.036071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 14233 MB memory:  -> device: 3, name: NVIDIA RTX A4000, pci bus id: 0000:c1:00.0, compute capability: 8.6
#  rmalization)
#
#  dense_2 (Dense)                (None, 64)           4160        ['batch_normalization_6[0][0]']
#
#  dense_3 (Dense)                (None, 64)           4160        ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64)          256         ['dense_2[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 64)          256         ['dense_3[0][0]']
#  rmalization)
#
#  z_mean (Dense)                 (None, 8)            520         ['batch_normalization_7[0][0]']
#
#  z_log_var (Dense)              (None, 8)            520         ['batch_normalization_8[0][0]']
#
#  sampling (Sampling)            (None, 8)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 576,432
# Trainable params: 575,504
# Non-trainable params: 928
# __________________________________________________________________________________________________

# %% [markdown]
# # Decoder Model

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation="relu")(latent_inputs)
x = layers.BatchNormalization()(x)
x = layers.Dense(x_shape[1]* x_shape[2]* x_shape[3], activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Reshape((x_shape[1], x_shape[2], x_shape[3]))(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(16, 3, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D(pool_size=(2, 1))(x)
x = layers.BatchNormalization()(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="linear", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8)]               0
#
#  dense_4 (Dense)             (None, 128)               1152
#
#  batch_normalization_9 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_5 (Dense)             (None, 4096)              528384
#
#  batch_normalization_10 (Bat  (None, 4096)             16384
#  chNormalization)
#
#  reshape (Reshape)           (None, 16, 8, 32)         0
#
#  conv2d_transpose (Conv2DTra  (None, 32, 16, 32)       9248
#  nspose)
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  batch_normalization_11 (Bat  (None, 16, 16, 32)       128
#  chNormalization)
#
#  conv2d_transpose_1 (Conv2DT  (None, 32, 32, 32)       9248
#  ranspose)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 32, 32)       0
#  2D)
#
#  batch_normalization_12 (Bat  (None, 16, 32, 32)       128
#  chNormalization)
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 64, 32)       9248
#  ranspose)
#
#  max_pooling2d_7 (MaxPooling  (None, 16, 64, 32)       0
#  2D)
#
#  batch_normalization_13 (Bat  (None, 16, 64, 32)       128
#  chNormalization)
#
#  conv2d_transpose_3 (Conv2DT  (None, 32, 128, 32)      9248
#  ranspose)
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 128, 32)      0
#  2D)
#
#  batch_normalization_14 (Bat  (None, 16, 128, 32)      128
#  chNormalization)
#
#  conv2d_transpose_4 (Conv2DT  (None, 32, 256, 16)      4624
#  ranspose)
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 256, 16)      0
#  2D)
#
#  batch_normalization_15 (Bat  (None, 16, 256, 16)      64
#  chNormalization)
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 256, 1)       145
#  ranspose)
#
# =================================================================
# Total params: 588,769
# Trainable params: 580,033
# Non-trainable params: 8,736
# _________________________________________________________________

# %% [markdown]
# # Training Model

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_test_reconstruction_loss', mode='min', verbose=1, patience=10)
print(X_train.shape)
autoencoder = VAE(encoder, decoder)
autoencoder.compile(optimizer=keras.optimizers.Adam(learning_rate = 1e-4))
history = autoencoder.fit(X_train, validation_data = (X_test[:20_000,:,:,:],X_test[:20_000,:,:,:]),
                  epochs=200, batch_size = 128, callbacks=[es])
# Out:
# (446711, 16, 256, 1)
# Epoch 1/200
# (None, 16, 256, 1)
# (None, 16, 256, 1)
# 2023-05-20 17:14:34.914940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-05-20 17:14:36.074572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-20 17:14:36.655464: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f364016fb70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-20 17:14:36.655559: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-05-20 17:14:36.655567: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-05-20 17:14:36.655571: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (2): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-05-20 17:14:36.655576: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (3): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-05-20 17:14:36.658641: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-20 17:14:36.837316: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3490/3490 [==============================] - 123s 32ms/step - loss: 1347.0819 - kl_loss: 1.0964 - reconstruction_loss: 24.6235 - val_test_loss: 1255.4927 - val_test_kl_loss: 1.0528 - val_test_reconstruction_loss: 18.5890
# Epoch 2/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1253.3332 - kl_loss: 1.0523 - reconstruction_loss: 18.0349 - val_test_loss: 1251.9613 - val_test_kl_loss: 1.0498 - val_test_reconstruction_loss: 17.6970
# Epoch 3/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1249.8817 - kl_loss: 1.0489 - reconstruction_loss: 17.5224 - val_test_loss: 1251.0796 - val_test_kl_loss: 1.0494 - val_test_reconstruction_loss: 17.3338
# Epoch 4/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1249.5494 - kl_loss: 1.0505 - reconstruction_loss: 17.2226 - val_test_loss: 1249.8217 - val_test_kl_loss: 1.0517 - val_test_reconstruction_loss: 17.1495
# Epoch 5/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1248.3489 - kl_loss: 1.0534 - reconstruction_loss: 16.9988 - val_test_loss: 1249.1985 - val_test_kl_loss: 1.0554 - val_test_reconstruction_loss: 16.9332
# Epoch 6/200
# 3490/3490 [==============================] - 109s 31ms/step - loss: 1247.4008 - kl_loss: 1.0572 - reconstruction_loss: 16.8258 - val_test_loss: 1248.4364 - val_test_kl_loss: 1.0594 - val_test_reconstruction_loss: 16.6408
# Epoch 7/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1247.1944 - kl_loss: 1.0611 - reconstruction_loss: 16.6618 - val_test_loss: 1248.1049 - val_test_kl_loss: 1.0627 - val_test_reconstruction_loss: 16.6658
# Epoch 8/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1246.7775 - kl_loss: 1.0643 - reconstruction_loss: 16.5191 - val_test_loss: 1247.8794 - val_test_kl_loss: 1.0664 - val_test_reconstruction_loss: 16.4046
# Epoch 9/200
# 3490/3490 [==============================] - 110s 32ms/step - loss: 1245.9825 - kl_loss: 1.0679 - reconstruction_loss: 16.3921 - val_test_loss: 1247.3160 - val_test_kl_loss: 1.0694 - val_test_reconstruction_loss: 16.3770
# Epoch 10/200
# 3490/3490 [==============================] - 110s 32ms/step - loss: 1247.6717 - kl_loss: 1.0709 - reconstruction_loss: 16.2742 - val_test_loss: 1246.9684 - val_test_kl_loss: 1.0725 - val_test_reconstruction_loss: 16.2231
# Epoch 11/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1244.4442 - kl_loss: 1.0740 - reconstruction_loss: 16.1729 - val_test_loss: 1246.6884 - val_test_kl_loss: 1.0754 - val_test_reconstruction_loss: 16.1992
# Epoch 12/200
# 3490/3490 [==============================] - 111s 32ms/step - loss: 1245.5253 - kl_loss: 1.0767 - reconstruction_loss: 16.0814 - val_test_loss: 1246.3557 - val_test_kl_loss: 1.0781 - val_test_reconstruction_loss: 16.1178
# Epoch 13/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1244.2930 - kl_loss: 1.0794 - reconstruction_loss: 15.9980 - val_test_loss: 1246.1766 - val_test_kl_loss: 1.0808 - val_test_reconstruction_loss: 15.9655
# Epoch 14/200
# 3490/3490 [==============================] - 110s 32ms/step - loss: 1246.0835 - kl_loss: 1.0821 - reconstruction_loss: 15.9912 - val_test_loss: 1246.1818 - val_test_kl_loss: 1.0835 - val_test_reconstruction_loss: 15.8472
# Epoch 15/200
# 3490/3490 [==============================] - 111s 32ms/step - loss: 1245.6941 - kl_loss: 1.0846 - reconstruction_loss: 15.9001 - val_test_loss: 1246.5820 - val_test_kl_loss: 1.0857 - val_test_reconstruction_loss: 16.0506
# Epoch 16/200
# 3490/3490 [==============================] - 110s 31ms/step - loss: 1243.3631 - kl_loss: 1.0868 - reconstruction_loss: 15.8758 - val_test_loss: 1245.8271 - val_test_kl_loss: 1.0878 - val_test_reconstruction_loss: 15.9007
# Epoch 17/200
# 3490/3490 [==============================] - 112s 32ms/step - loss: 1243.6783 - kl_loss: 1.0887 - reconstruction_loss: 15.8348 - val_test_loss: 1245.7625 - val_test_kl_loss: 1.0897 - val_test_reconstruction_loss: 15.8525
# Epoch 18/200
# 3490/3490 [==============================] - 111s 32ms/step - loss: 1244.9851 - kl_loss: 1.0906 - reconstruction_loss: 15.8143 - val_test_loss: 1245.4443 - val_test_kl_loss: 1.0916 - val_test_reconstruction_loss: 15.8377
# Epoch 19/200
# 3490/3490 [==============================] - 111s 32ms/step - loss: 1244.9336 - kl_loss: 1.0924 - reconstruction_loss: 15.7953 - val_test_loss: 1245.4135 - val_test_kl_loss: 1.0933 - val_test_reconstruction_loss: 15.6990
# Epoch 20/200
# 3490/3490 [==============================] - 111s 32ms/step - loss: 1243.0162 - kl_loss: 1.0941 - reconstruction_loss: 15.7470 - val_test_loss: 1245.6613 - val_test_kl_loss: 1.0948 - val_test_reconstruction_loss: 15.8136
# Epoch 21/200
# 3490/3490 [==============================] - 109s 31ms/step - loss: 1243.1920 - kl_loss: 1.0955 - reconstruction_loss: 15.7381 - val_test_loss: 1245.3711 - val_test_kl_loss: 1.0963 - val_test_reconstruction_loss: 15.7223
# Epoch 22/200
# 3490/3490 [==============================] - 109s 31ms/step - loss: 1242.6655 - kl_loss: 1.0970 - reconstruction_loss: 15.7206 - val_test_loss: 1245.0168 - val_test_kl_loss: 1.0977 - val_test_reconstruction_loss: 15.7314
# Epoch 23/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.8208 - kl_loss: 1.0984 - reconstruction_loss: 15.7064 - val_test_loss: 1245.0450 - val_test_kl_loss: 1.0991 - val_test_reconstruction_loss: 15.6897
# Epoch 24/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1244.3731 - kl_loss: 1.0998 - reconstruction_loss: 15.6770 - val_test_loss: 1245.1375 - val_test_kl_loss: 1.1005 - val_test_reconstruction_loss: 15.8017
# Epoch 25/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.7694 - kl_loss: 1.1011 - reconstruction_loss: 15.6614 - val_test_loss: 1244.8676 - val_test_kl_loss: 1.1017 - val_test_reconstruction_loss: 15.6429
# Epoch 26/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.8498 - kl_loss: 1.1023 - reconstruction_loss: 15.6521 - val_test_loss: 1245.0582 - val_test_kl_loss: 1.1030 - val_test_reconstruction_loss: 15.7595
# Epoch 27/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.1131 - kl_loss: 1.1036 - reconstruction_loss: 15.6576 - val_test_loss: 1244.8748 - val_test_kl_loss: 1.1042 - val_test_reconstruction_loss: 15.5548
# Epoch 28/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.3618 - kl_loss: 1.1048 - reconstruction_loss: 15.6433 - val_test_loss: 1244.7010 - val_test_kl_loss: 1.1054 - val_test_reconstruction_loss: 15.6555
# Epoch 29/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.3149 - kl_loss: 1.1059 - reconstruction_loss: 15.6284 - val_test_loss: 1244.6471 - val_test_kl_loss: 1.1065 - val_test_reconstruction_loss: 15.6016
# Epoch 30/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1244.1331 - kl_loss: 1.1071 - reconstruction_loss: 15.6595 - val_test_loss: 1244.7332 - val_test_kl_loss: 1.1077 - val_test_reconstruction_loss: 15.6836
# Epoch 31/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.2223 - kl_loss: 1.1082 - reconstruction_loss: 15.6268 - val_test_loss: 1244.6095 - val_test_kl_loss: 1.1088 - val_test_reconstruction_loss: 15.5931
# Epoch 32/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.6780 - kl_loss: 1.1093 - reconstruction_loss: 15.6067 - val_test_loss: 1244.5426 - val_test_kl_loss: 1.1099 - val_test_reconstruction_loss: 15.5674
# Epoch 33/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1242.4157 - kl_loss: 1.1104 - reconstruction_loss: 15.5857 - val_test_loss: 1244.5428 - val_test_kl_loss: 1.1110 - val_test_reconstruction_loss: 15.5671
# Epoch 34/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1242.9278 - kl_loss: 1.1115 - reconstruction_loss: 15.5437 - val_test_loss: 1244.3955 - val_test_kl_loss: 1.1121 - val_test_reconstruction_loss: 15.5558
# Epoch 35/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1241.9297 - kl_loss: 1.1126 - reconstruction_loss: 15.5188 - val_test_loss: 1244.6488 - val_test_kl_loss: 1.1132 - val_test_reconstruction_loss: 15.6112
# Epoch 36/200
# 3490/3490 [==============================] - 106s 30ms/step - loss: 1243.0505 - kl_loss: 1.1138 - reconstruction_loss: 15.4830 - val_test_loss: 1244.4261 - val_test_kl_loss: 1.1144 - val_test_reconstruction_loss: 15.4834
# Epoch 37/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.4322 - kl_loss: 1.1149 - reconstruction_loss: 15.4890 - val_test_loss: 1244.3215 - val_test_kl_loss: 1.1155 - val_test_reconstruction_loss: 15.4839
# Epoch 38/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1244.9389 - kl_loss: 1.1161 - reconstruction_loss: 15.4656 - val_test_loss: 1244.1783 - val_test_kl_loss: 1.1167 - val_test_reconstruction_loss: 15.4917
# Epoch 39/200
# 3490/3490 [==============================] - 2105s 603ms/step - loss: 1241.7230 - kl_loss: 1.1173 - reconstruction_loss: 15.4514 - val_test_loss: 1244.0721 - val_test_kl_loss: 1.1180 - val_test_reconstruction_loss: 15.4813
# Epoch 40/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1243.0779 - kl_loss: 1.1187 - reconstruction_loss: 15.3734 - val_test_loss: 1243.7977 - val_test_kl_loss: 1.1195 - val_test_reconstruction_loss: 15.2953
# Epoch 41/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.8768 - kl_loss: 1.1203 - reconstruction_loss: 15.2939 - val_test_loss: 1243.5927 - val_test_kl_loss: 1.1212 - val_test_reconstruction_loss: 15.1715
# Epoch 42/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1243.1267 - kl_loss: 1.1220 - reconstruction_loss: 15.1943 - val_test_loss: 1243.4373 - val_test_kl_loss: 1.1230 - val_test_reconstruction_loss: 15.2095
# Epoch 43/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1241.5969 - kl_loss: 1.1239 - reconstruction_loss: 15.1069 - val_test_loss: 1243.1606 - val_test_kl_loss: 1.1249 - val_test_reconstruction_loss: 15.0933
# Epoch 44/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1241.6078 - kl_loss: 1.1258 - reconstruction_loss: 15.0388 - val_test_loss: 1243.0378 - val_test_kl_loss: 1.1268 - val_test_reconstruction_loss: 15.0289
# Epoch 45/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.8127 - kl_loss: 1.1277 - reconstruction_loss: 14.9961 - val_test_loss: 1242.8632 - val_test_kl_loss: 1.1287 - val_test_reconstruction_loss: 15.0128
# Epoch 46/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1241.7186 - kl_loss: 1.1296 - reconstruction_loss: 14.9794 - val_test_loss: 1242.7518 - val_test_kl_loss: 1.1306 - val_test_reconstruction_loss: 14.9585
# Epoch 47/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1241.1027 - kl_loss: 1.1316 - reconstruction_loss: 14.9179 - val_test_loss: 1242.8295 - val_test_kl_loss: 1.1326 - val_test_reconstruction_loss: 14.9470
# Epoch 48/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.8470 - kl_loss: 1.1335 - reconstruction_loss: 14.9003 - val_test_loss: 1242.8167 - val_test_kl_loss: 1.1345 - val_test_reconstruction_loss: 14.8809
# Epoch 49/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.6033 - kl_loss: 1.1354 - reconstruction_loss: 14.8682 - val_test_loss: 1242.5457 - val_test_kl_loss: 1.1363 - val_test_reconstruction_loss: 14.9687
# Epoch 50/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1242.1514 - kl_loss: 1.1372 - reconstruction_loss: 14.8407 - val_test_loss: 1242.3549 - val_test_kl_loss: 1.1382 - val_test_reconstruction_loss: 14.8125
# Epoch 51/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.3688 - kl_loss: 1.1391 - reconstruction_loss: 14.8121 - val_test_loss: 1242.3049 - val_test_kl_loss: 1.1400 - val_test_reconstruction_loss: 14.7981
# Epoch 52/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.9472 - kl_loss: 1.1409 - reconstruction_loss: 14.7911 - val_test_loss: 1242.3857 - val_test_kl_loss: 1.1418 - val_test_reconstruction_loss: 14.8203
# Epoch 53/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.2655 - kl_loss: 1.1427 - reconstruction_loss: 14.7869 - val_test_loss: 1242.2354 - val_test_kl_loss: 1.1436 - val_test_reconstruction_loss: 14.8163
# Epoch 54/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.2025 - kl_loss: 1.1445 - reconstruction_loss: 14.7913 - val_test_loss: 1242.1400 - val_test_kl_loss: 1.1454 - val_test_reconstruction_loss: 14.8462
# Epoch 55/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.8300 - kl_loss: 1.1462 - reconstruction_loss: 14.8132 - val_test_loss: 1242.1324 - val_test_kl_loss: 1.1471 - val_test_reconstruction_loss: 14.8668
# Epoch 56/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1241.2548 - kl_loss: 1.1479 - reconstruction_loss: 14.7809 - val_test_loss: 1242.0302 - val_test_kl_loss: 1.1488 - val_test_reconstruction_loss: 14.8578
# Epoch 57/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.3688 - kl_loss: 1.1496 - reconstruction_loss: 14.8032 - val_test_loss: 1242.0909 - val_test_kl_loss: 1.1505 - val_test_reconstruction_loss: 14.7662
# Epoch 58/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.7341 - kl_loss: 1.1513 - reconstruction_loss: 14.8117 - val_test_loss: 1242.0002 - val_test_kl_loss: 1.1521 - val_test_reconstruction_loss: 14.6808
# Epoch 59/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.6549 - kl_loss: 1.1529 - reconstruction_loss: 14.7683 - val_test_loss: 1241.9004 - val_test_kl_loss: 1.1538 - val_test_reconstruction_loss: 14.8026
# Epoch 60/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1241.1575 - kl_loss: 1.1545 - reconstruction_loss: 14.7478 - val_test_loss: 1241.8951 - val_test_kl_loss: 1.1554 - val_test_reconstruction_loss: 14.7390
# Epoch 61/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.3109 - kl_loss: 1.1561 - reconstruction_loss: 14.7256 - val_test_loss: 1241.9579 - val_test_kl_loss: 1.1570 - val_test_reconstruction_loss: 14.6650
# Epoch 62/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.1145 - kl_loss: 1.1577 - reconstruction_loss: 14.7220 - val_test_loss: 1241.7716 - val_test_kl_loss: 1.1585 - val_test_reconstruction_loss: 14.7776
# Epoch 63/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.8702 - kl_loss: 1.1592 - reconstruction_loss: 14.6964 - val_test_loss: 1241.6458 - val_test_kl_loss: 1.1600 - val_test_reconstruction_loss: 14.6970
# Epoch 64/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1238.8764 - kl_loss: 1.1607 - reconstruction_loss: 14.7086 - val_test_loss: 1241.6554 - val_test_kl_loss: 1.1615 - val_test_reconstruction_loss: 14.6463
# Epoch 65/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.7588 - kl_loss: 1.1622 - reconstruction_loss: 14.6741 - val_test_loss: 1241.7498 - val_test_kl_loss: 1.1630 - val_test_reconstruction_loss: 14.6182
# Epoch 66/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.6240 - kl_loss: 1.1637 - reconstruction_loss: 14.6733 - val_test_loss: 1241.4886 - val_test_kl_loss: 1.1644 - val_test_reconstruction_loss: 14.5967
# Epoch 67/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.3533 - kl_loss: 1.1651 - reconstruction_loss: 14.6805 - val_test_loss: 1241.5879 - val_test_kl_loss: 1.1658 - val_test_reconstruction_loss: 14.6852
# Epoch 68/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.7177 - kl_loss: 1.1665 - reconstruction_loss: 14.6546 - val_test_loss: 1241.6082 - val_test_kl_loss: 1.1672 - val_test_reconstruction_loss: 14.6159
# Epoch 69/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.2126 - kl_loss: 1.1679 - reconstruction_loss: 14.6344 - val_test_loss: 1241.3644 - val_test_kl_loss: 1.1686 - val_test_reconstruction_loss: 14.6543
# Epoch 70/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1241.0586 - kl_loss: 1.1692 - reconstruction_loss: 14.6451 - val_test_loss: 1241.3766 - val_test_kl_loss: 1.1699 - val_test_reconstruction_loss: 14.5097
# Epoch 71/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1240.0784 - kl_loss: 1.1705 - reconstruction_loss: 14.6897 - val_test_loss: 1241.3424 - val_test_kl_loss: 1.1712 - val_test_reconstruction_loss: 14.6230
# Epoch 72/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.7919 - kl_loss: 1.1719 - reconstruction_loss: 14.6086 - val_test_loss: 1241.3750 - val_test_kl_loss: 1.1725 - val_test_reconstruction_loss: 14.5632
# Epoch 73/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.9414 - kl_loss: 1.1731 - reconstruction_loss: 14.6198 - val_test_loss: 1241.2343 - val_test_kl_loss: 1.1738 - val_test_reconstruction_loss: 14.5235
# Epoch 74/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.3586 - kl_loss: 1.1744 - reconstruction_loss: 14.6758 - val_test_loss: 1241.5645 - val_test_kl_loss: 1.1751 - val_test_reconstruction_loss: 14.3864
# Epoch 75/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.6573 - kl_loss: 1.1757 - reconstruction_loss: 14.6078 - val_test_loss: 1241.1711 - val_test_kl_loss: 1.1763 - val_test_reconstruction_loss: 14.5436
# Epoch 76/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1238.8991 - kl_loss: 1.1769 - reconstruction_loss: 14.6151 - val_test_loss: 1241.2867 - val_test_kl_loss: 1.1775 - val_test_reconstruction_loss: 14.8272
# Epoch 77/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.0066 - kl_loss: 1.1781 - reconstruction_loss: 14.5866 - val_test_loss: 1241.0884 - val_test_kl_loss: 1.1787 - val_test_reconstruction_loss: 14.6736
# Epoch 78/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1240.1760 - kl_loss: 1.1793 - reconstruction_loss: 14.5570 - val_test_loss: 1241.1270 - val_test_kl_loss: 1.1799 - val_test_reconstruction_loss: 14.5080
# Epoch 79/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.6567 - kl_loss: 1.1805 - reconstruction_loss: 14.5644 - val_test_loss: 1243.3319 - val_test_kl_loss: 1.1811 - val_test_reconstruction_loss: 15.1000
# Epoch 80/200
# 3490/3490 [==============================] - 108s 31ms/step - loss: 1239.7827 - kl_loss: 1.1816 - reconstruction_loss: 14.5336 - val_test_loss: 1240.9779 - val_test_kl_loss: 1.1822 - val_test_reconstruction_loss: 14.4309
# Epoch 81/200
# 3490/3490 [==============================] - 107s 31ms/step - loss: 1239.1042 - kl_loss: 1.1828 - reconstruction_loss: 14.4947 - val_test_loss: 1240.9512 - val_test_kl_loss: 1.1833 - val_test_reconstruction_loss: 14.6162
# Epoch 82/200
# 1299/3490 [==========>...................] - ETA: 1:06 - loss: 1240.6821 - kl_loss: 1.1835 - reconstruction_loss: 14.5452
# KeyboardInterrupt

# %%
import pandas as pd
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(20,10))
plt.plot(history.history['reconstruction_loss'])
plt.plot(history.history['val_test_reconstruction_loss'])
plt.title('Model MSE Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train Loss', 'Validation Loss'], loc='upper left')
# plt.yscale('log')
plt.grid()
plt.savefig("plots/training_loss.pdf", format='pdf')
plt.show()

training_history = {}
training_history['train'] = history.history['reconstruction_loss']
training_history['test'] = history.history['val_test_reconstruction_loss']
df = pd.DataFrame(training_history)
df.to_csv("plots/training_loss.csv")

# %%
from datetime import datetime
now = datetime.now() # current date and time
date_time = now.strftime("%m/%d/%Y, %H:%M:%S")
idtag = date_time.replace(', ','-').replace('/','-').replace(':','-')
print(idtag)

autoencoder.save_weights("models/full-weights-"+idtag, save_format="tf")

# %%
# autoencoder.load_weights("models/full-weights-"+idtag)
# autoencoder.compile(optimizer=keras.optimizers.Adam(lr = 1e-4), run_eagerly=True)

# %% [markdown]
# # Test Reconstruction

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
index = 12

beam_reconstruction = autoencoder.decoder.predict(autoencoder.encoder.predict(X_test[index:index+1,:,:,:])[-1])
print(beam_reconstruction.shape)

plt.rcParams.update({'font.size': 20})
plt.figure(figsize=(10,5))
plt.title("Reconstruction of Observation")
plt.imshow(beam_reconstruction[0,:,:,0], cmap='hot', interpolation='nearest', aspect=3)
plt.ylabel("Time Bins [18.7s]")
plt.xlabel("Frequency Bins [2.89Hz]")
plt.savefig("plots/reconstruction.pdf", format='pdf')

# %%
plt.rcParams.update({'font.size': 20})
plt.figure(figsize=(10,5))
plt.title("Real Observation")
plt.imshow(X_test[index,:,:,0], cmap='hot', interpolation='nearest', aspect=3)
plt.ylabel("Time Bins [18.7s]")
plt.xlabel("Frequency Bins [2.89Hz]")
plt.savefig("plots/real.pdf", format='pdf')

# %%
ind = np.random.randint(20_000, X_test.shape[0], size=(10))
font_size = 80
plt.rcParams.update({'font.size': font_size})

f, ax = plt.subplots(2, 8, sharey=True, figsize=(100, 30), constrained_layout=True)

for j in range(8):
    inde = ind[j]
    beam_reconstruction = autoencoder.decoder.predict(autoencoder.encoder.predict(X_test[inde:inde+1,:,:,:])[-1])
    im = ax[0,j].imshow(beam_reconstruction[0,:,:,0], cmap='hot',
                        interpolation='nearest', aspect="auto")
    ax[1,j].imshow(X_test[inde,:,:,0], cmap='hot', interpolation='nearest', aspect="auto")
    if j == 0:
        ax[1,j].text(-50, 7, 'Time [18.7s]', ha='center', va='center', rotation='vertical',  fontsize=font_size)
        ax[1,j].text(-100, 7, 'Reconstruction', ha='center', va='center', rotation='vertical', 
                     fontsize=font_size+20)
        ax[0,j].text(-100, 7, 'Real Obs', ha='center', va='center', rotation='vertical',  fontsize=font_size  +20)
        ax[0,j].text(-50, 7, 'Time [18.7s]', ha='center', va='center', rotation='vertical',  fontsize=font_size)
    ax[1,j].set_xlabel("Frequency [2.89 Hz]",  fontsize=font_size-5)  
    
cbaxes = f.add_axes([1.01, 0.2, 0.015, 0.6]) 
cbar = f.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
f.text(1.06, 0.5, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size+10)

plt.savefig("plots/reconstruction_test.pdf", format="pdf")

# %% [markdown]
# # Preturb Axis

# %%
import matplotlib.pyplot as plt
from copy import deepcopy
# %matplotlib inline
index = 13
rows = 10
rate = 0.5
total_images = []
vec = autoencoder.encoder.predict(X_test[index:index+1,:,:,:])[0]

for i in range(latent_dim):
    sub_images = []
    perturb = []
    for k in range(rows):
        new_vec = deepcopy(vec)
        perturb.append(rate*k-rate)
        new_vec[0,i] += rate*k-rate
        image = autoencoder.decoder(new_vec)
        sub_images.append(image)
    total_images.append(sub_images)
    
f, ax = plt.subplots(rows, latent_dim, sharey=True, figsize=(100, 100), constrained_layout=True)

for j in range(latent_dim):
    ax[0,j].set_title("$z_{index}$".format(index=j), fontsize=font_size+100 )
    for t in range(rows):
        inde = ind[j]
        im = ax[t,j].imshow(total_images[j][t][0,:,:,0], cmap='hot',
                            interpolation='nearest', aspect="auto")
        if j == 0:
            ax[t,j].text(-100, 7, str(perturb[t]), ha='center', va='center', rotation='vertical', 
                     fontsize=font_size+20)
            ax[t,j].text(-50, 7, 'Time [18.7s]', ha='center', va='center', rotation='vertical',  fontsize=font_size)
        ax[rows-1,j].set_xlabel("Frequency [2.89 Hz]",  fontsize=font_size-5)  
    
cbaxes = f.add_axes([1.01, 0.2, 0.015, 0.6]) 
cbar = f.colorbar(im, cax=cbaxes)
cbar.ax.tick_params(labelsize=font_size)
f.text(1.06, 0.5, 'Power [normalized]', ha='center', va='center', rotation=270, 
       fontsize=font_size+10)

plt.savefig("plots/perturb.pdf", format="pdf")
