# %%
import numpy as np
import setigen as stg
from blimpy import Waterfall
import matplotlib.pyplot as plt
import random
import os
from astropy import units as u
from tqdm import tqdm
from sklearn.metrics import silhouette_score
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# 2023-08-24 10:03:28.378008: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def painting(data):
    all_data = []
    labels = []
    for c in range(num_classes):
        drift = 2*random.random()*(-1)**random.randint(0,2)
        snr = random.randint(100, 150)
        width = random.randint(20, 50)
        for s in range(num_samples_per_class):
            index = random.randint(0, data.shape[0]-1)
            window = data[index, :,:]
            
            start = random.randint(50, 180)
            
            frame = stg.Frame.from_data(df=2.7939677238464355*u.Hz,
                                        dt=18.253611008*u.s,
                                        fch1=1289*u.MHz,
                                        ascending=True,
                                        data=window)
            frame.add_signal(stg.constant_path(
                                        f_start=frame.get_frequency(index=start),
                                       drift_rate=drift*u.Hz/u.s),
                                      stg.constant_t_profile(level=frame.get_intensity(snr=snr)),
                                      stg.gaussian_f_profile(width=width*u.Hz),
                                      stg.constant_bp_profile(level=1))
            all_data.append(frame.data)
            labels.append(c)
    all_data = np.array(all_data)
    labels = np.vstack(labels)
    return all_data, labels

# %%
import cv2
import numpy as np

def transform(data):
    final = []
    for i in range(data.shape[0]):
        img = np.repeat(data[i,:, :], 3, axis=2)
        res = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
        final.append(res)
    return np.array(final)

# %%
from tqdm import tqdm
import gc

def normalize(data):
    epsilon = 1
    min_val = data.min()
    data = data - min_val + epsilon
    new_data = np.log(data)
    min_val = data.min()
    max_val = data.max()
    final_data = (data - min_val) / (max_val - min_val)
    return final_data
    
def normalize_data(data):
    for i in range(data.shape[0]):
        data[i,:,:] = normalize(data[i,:,:, :])
    return data

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras import Model

model = ResNet50(include_top=True,
                weights='imagenet',
                input_tensor=None,
                input_shape=None,
                pooling=None,
                classes=1000
                )
truncated_model = Model(inputs = model.layers[0].input, outputs = model.layers[-1].output)
truncated_model.summary()
truncated_model.compile(optimizer='rmsprop')
# Out:
# 2023-08-24 10:03:30.605290: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-24 10:03:30.995300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13888 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:61:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
def idealized(num=10_000):
    drift = drift = (-1)**(random.randint(0,2)) * 2 *random.random()
    snr = 50*random.random() +20
    width = 50*random.random() +20
    start = random.randint(50, 180)
    data = []
    labels = []
    for tag in range(4):
        label_vec = np.zeros(4)
        label_vec[tag] = 1
        for i in range(num):
            if tag == 0:
#             everything but drif
                snr = 50*random.random() +20
                width = 50*random.random() +20
                start = random.randint(50, 180)
            elif tag == 1:
#             everything but snr
                drift = (-1)**(random.randint(0,2)) * 2 *random.random()
                width = 50*random.random() +20
                start = random.randint(50, 180)
            elif tag == 2:
#             everything but width
                drift = (-1)**(random.randint(0,2)) * 2 *random.random()
                snr = 50*random.random() +20
                start = random.randint(50, 180)
            elif tag == 3:
#             everything but start
                drift = (-1)**(random.randint(0,2)) * 2 *random.random()
                snr = 50*random.random() +20
                width = 50*random.random() +20

            frame = stg.Frame(fchans=256*u.pixel,
                              tchans=16*u.pixel,
                              df=2.7939677238464355*u.Hz,
                              dt=18.253611008*u.s,
                              fch1=6095.214842353016*u.MHz)
            noise = frame.add_noise(x_mean=1, noise_type='chi2')
            frame.add_signal(stg.constant_path(
                                        f_start=frame.get_frequency(index=start),
                                       drift_rate=drift*u.Hz/u.s),
                                      stg.constant_t_profile(level=frame.get_intensity(snr=snr)),
                                      stg.gaussian_f_profile(width=width*u.Hz),
                                      stg.constant_bp_profile(level=1))
            data.append(frame.data)
            labels.append(label_vec)
    data = np.array(data)
    labels = np.vstack(labels)
    return data, labels

# %%
def absolute_diff(X, labels):
    new_x = []
    new_labels = []
    one = np.arange(0,10000)
    two = np.arange(10000,20000)
    three = np.arange(20000,30000)
    four = np.arange(30000,40000)
    for i in range(X.shape[0] -1):
        if np.argmax(labels[i,:]) == np.argmax(labels[i+1,:]): 
            index = np.argmax(labels[i,:])
            if index == 0:
                sample = np.random.choice(one, size = 1000)
            elif index == 1:
                sample = np.random.choice(two, size = 1000)
            elif index == 2:
                sample = np.random.choice(three, size = 1000)
            elif index == 3:
                sample = np.random.choice(four, size = 1000)
            diff = abs(X[i,:] - X[sample,:])
            diff = np.mean(diff, axis = 0)
            new_x.append(diff)
            new_labels.append(labels[i,:])
            
    return np.array(new_x), np.vstack(new_labels)

# %%
import os
from tqdm import tqdm
import keras
total_scores = []
for i in tqdm(range(10)):
    idealized_signals, labels = idealized(num = 10_000)

    input_data = transform(np.expand_dims(idealized_signals, axis = -1))
    gc.collect()
    input_data = normalize_data(input_data)
    print(input_data[0,:,:].max(), input_data[0,:,:].min())
    splits = input_data.shape[0]//1_000
    X = []
    for i in range(splits):
        tensor = tf.convert_to_tensor(input_data[i*1_000:(i+1)*1_000, :,:,:], dtype=tf.float32)
        X.append(truncated_model(tensor))
    X = np.vstack(X)
    print(X.shape)
    X, labels = absolute_diff(X, labels)
    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.33, random_state=42)

    linear = keras.Sequential(name="my_sequential")
    # linear.add(layers.Dense(1000, activation="linear", name="layer1"))
    linear.add(layers.Dense(4, activation="softmax", name="layer2"))

    linear.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    linear.fit(X_train, y_train, epochs=150, batch_size=128, validation_split = 0.1, shuffle=True)
    results = linear.evaluate(X_test, y_test)
    print(results)
    total_scores.append(results[-1])
# Out:
#   0%|                                                                                              | 0/10 [00:00<?, ?it/s]
# 1.0 0.0
# 2023-08-24 10:08:47.771197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-08-24 10:08:49.747602: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:49.747684: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.88GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:49.876297: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:49.876329: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:49.876345: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:49.876360: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:50.580945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-24 10:08:53.677443: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:53.677544: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:53.771304: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-08-24 10:08:53.771340: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# (40000, 1000)
# Epoch 1/150
# 2023-08-24 10:10:21.609719: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f2b940077b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-24 10:10:21.609835: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-08-24 10:10:21.614405: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-24 10:10:22.206395: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 189/189 [==============================] - 2s 3ms/step - loss: 1.3859 - accuracy: 0.2604 - val_loss: 1.3857 - val_accuracy: 0.2425
# Epoch 2/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3851 - accuracy: 0.2543 - val_loss: 1.3850 - val_accuracy: 0.2444
# Epoch 3/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3843 - accuracy: 0.2742 - val_loss: 1.3841 - val_accuracy: 0.2549
# Epoch 4/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3835 - accuracy: 0.2760 - val_loss: 1.3833 - val_accuracy: 0.2537
# Epoch 5/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3827 - accuracy: 0.2876 - val_loss: 1.3827 - val_accuracy: 0.2534
# Epoch 6/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3819 - accuracy: 0.2684 - val_loss: 1.3818 - val_accuracy: 0.2657
# Epoch 7/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3811 - accuracy: 0.3739 - val_loss: 1.3811 - val_accuracy: 0.2631
# Epoch 8/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3803 - accuracy: 0.3432 - val_loss: 1.3804 - val_accuracy: 0.2608
# Epoch 9/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3795 - accuracy: 0.2944 - val_loss: 1.3798 - val_accuracy: 0.2575
# Epoch 10/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3787 - accuracy: 0.3442 - val_loss: 1.3789 - val_accuracy: 0.2646
# Epoch 11/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3779 - accuracy: 0.3117 - val_loss: 1.3779 - val_accuracy: 0.3235
# Epoch 12/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3771 - accuracy: 0.4316 - val_loss: 1.3773 - val_accuracy: 0.3657
# Epoch 13/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3763 - accuracy: 0.3882 - val_loss: 1.3764 - val_accuracy: 0.2828
# Epoch 14/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3755 - accuracy: 0.4141 - val_loss: 1.3758 - val_accuracy: 0.3440
# Epoch 15/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3747 - accuracy: 0.4234 - val_loss: 1.3751 - val_accuracy: 0.4000
# Epoch 16/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3740 - accuracy: 0.4247 - val_loss: 1.3744 - val_accuracy: 0.3836
# Epoch 17/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3732 - accuracy: 0.3416 - val_loss: 1.3737 - val_accuracy: 0.4149
# Epoch 18/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3724 - accuracy: 0.4272 - val_loss: 1.3728 - val_accuracy: 0.4534
# Epoch 19/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3716 - accuracy: 0.4586 - val_loss: 1.3721 - val_accuracy: 0.4317
# Epoch 20/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3709 - accuracy: 0.4138 - val_loss: 1.3712 - val_accuracy: 0.4631
# Epoch 21/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3701 - accuracy: 0.4668 - val_loss: 1.3705 - val_accuracy: 0.4500
# Epoch 22/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3693 - accuracy: 0.4521 - val_loss: 1.3699 - val_accuracy: 0.4459
# Epoch 23/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3685 - accuracy: 0.4605 - val_loss: 1.3692 - val_accuracy: 0.4440
# Epoch 24/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3678 - accuracy: 0.4671 - val_loss: 1.3684 - val_accuracy: 0.4403
# Epoch 25/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3670 - accuracy: 0.4541 - val_loss: 1.3676 - val_accuracy: 0.4791
# Epoch 26/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3662 - accuracy: 0.5132 - val_loss: 1.3669 - val_accuracy: 0.4623
# Epoch 27/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3655 - accuracy: 0.4710 - val_loss: 1.3661 - val_accuracy: 0.4586
# Epoch 28/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3647 - accuracy: 0.4526 - val_loss: 1.3653 - val_accuracy: 0.4761
# Epoch 29/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3640 - accuracy: 0.4957 - val_loss: 1.3648 - val_accuracy: 0.4631
# Epoch 30/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3632 - accuracy: 0.5004 - val_loss: 1.3642 - val_accuracy: 0.4373
# Epoch 31/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3625 - accuracy: 0.4627 - val_loss: 1.3633 - val_accuracy: 0.4586
# Epoch 32/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3617 - accuracy: 0.5016 - val_loss: 1.3627 - val_accuracy: 0.4369
# Epoch 33/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3610 - accuracy: 0.4739 - val_loss: 1.3618 - val_accuracy: 0.4694
# Epoch 34/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3602 - accuracy: 0.4885 - val_loss: 1.3611 - val_accuracy: 0.4675
# Epoch 35/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3595 - accuracy: 0.4671 - val_loss: 1.3603 - val_accuracy: 0.4933
# Epoch 36/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3587 - accuracy: 0.5093 - val_loss: 1.3596 - val_accuracy: 0.5220
# Epoch 37/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3580 - accuracy: 0.5228 - val_loss: 1.3590 - val_accuracy: 0.4813
# Epoch 38/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3572 - accuracy: 0.4789 - val_loss: 1.3582 - val_accuracy: 0.4791
# Epoch 39/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3565 - accuracy: 0.5032 - val_loss: 1.3575 - val_accuracy: 0.4858
# Epoch 40/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3558 - accuracy: 0.5102 - val_loss: 1.3569 - val_accuracy: 0.5101
# Epoch 41/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3550 - accuracy: 0.4954 - val_loss: 1.3563 - val_accuracy: 0.5175
# Epoch 42/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3543 - accuracy: 0.5246 - val_loss: 1.3556 - val_accuracy: 0.4892
# Epoch 43/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3536 - accuracy: 0.5322 - val_loss: 1.3550 - val_accuracy: 0.4881
# Epoch 44/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3529 - accuracy: 0.4924 - val_loss: 1.3542 - val_accuracy: 0.5041
# Epoch 45/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3522 - accuracy: 0.5327 - val_loss: 1.3535 - val_accuracy: 0.4888
# Epoch 46/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3514 - accuracy: 0.5252 - val_loss: 1.3528 - val_accuracy: 0.5015
# Epoch 47/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3508 - accuracy: 0.5276 - val_loss: 1.3522 - val_accuracy: 0.4918
# Epoch 48/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3500 - accuracy: 0.5045 - val_loss: 1.3514 - val_accuracy: 0.4989
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3493 - accuracy: 0.5171 - val_loss: 1.3507 - val_accuracy: 0.5097
# Epoch 50/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3486 - accuracy: 0.5076 - val_loss: 1.3501 - val_accuracy: 0.5101
# Epoch 51/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3479 - accuracy: 0.5257 - val_loss: 1.3494 - val_accuracy: 0.5410
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3472 - accuracy: 0.5313 - val_loss: 1.3488 - val_accuracy: 0.5179
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3465 - accuracy: 0.5650 - val_loss: 1.3482 - val_accuracy: 0.5011
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3458 - accuracy: 0.5147 - val_loss: 1.3475 - val_accuracy: 0.5280
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3451 - accuracy: 0.5536 - val_loss: 1.3467 - val_accuracy: 0.5257
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3444 - accuracy: 0.5285 - val_loss: 1.3460 - val_accuracy: 0.5422
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3437 - accuracy: 0.5457 - val_loss: 1.3455 - val_accuracy: 0.5231
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3430 - accuracy: 0.5177 - val_loss: 1.3446 - val_accuracy: 0.5377
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3423 - accuracy: 0.5759 - val_loss: 1.3442 - val_accuracy: 0.5175
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3416 - accuracy: 0.5122 - val_loss: 1.3433 - val_accuracy: 0.5437
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3410 - accuracy: 0.5548 - val_loss: 1.3427 - val_accuracy: 0.5392
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3403 - accuracy: 0.5562 - val_loss: 1.3421 - val_accuracy: 0.5131
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3396 - accuracy: 0.5408 - val_loss: 1.3414 - val_accuracy: 0.5239
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3389 - accuracy: 0.5302 - val_loss: 1.3407 - val_accuracy: 0.5399
# Epoch 65/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3382 - accuracy: 0.5729 - val_loss: 1.3403 - val_accuracy: 0.5336
# Epoch 66/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3376 - accuracy: 0.5489 - val_loss: 1.3395 - val_accuracy: 0.5366
# Epoch 67/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3369 - accuracy: 0.5489 - val_loss: 1.3389 - val_accuracy: 0.5369
# Epoch 68/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3362 - accuracy: 0.5572 - val_loss: 1.3382 - val_accuracy: 0.5123
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3356 - accuracy: 0.5555 - val_loss: 1.3376 - val_accuracy: 0.5287
# Epoch 70/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3349 - accuracy: 0.5727 - val_loss: 1.3370 - val_accuracy: 0.5168
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3342 - accuracy: 0.5580 - val_loss: 1.3363 - val_accuracy: 0.5295
# Epoch 72/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3335 - accuracy: 0.5531 - val_loss: 1.3357 - val_accuracy: 0.5392
# Epoch 73/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3329 - accuracy: 0.5584 - val_loss: 1.3352 - val_accuracy: 0.5243
# Epoch 74/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3322 - accuracy: 0.5565 - val_loss: 1.3344 - val_accuracy: 0.5362
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3315 - accuracy: 0.5552 - val_loss: 1.3338 - val_accuracy: 0.5437
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3309 - accuracy: 0.5620 - val_loss: 1.3332 - val_accuracy: 0.5455
# Epoch 77/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3302 - accuracy: 0.5753 - val_loss: 1.3326 - val_accuracy: 0.5399
# Epoch 78/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3295 - accuracy: 0.5469 - val_loss: 1.3318 - val_accuracy: 0.5481
# Epoch 79/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3289 - accuracy: 0.5688 - val_loss: 1.3313 - val_accuracy: 0.5470
# Epoch 80/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3283 - accuracy: 0.5562 - val_loss: 1.3306 - val_accuracy: 0.5541
# Epoch 81/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3276 - accuracy: 0.5753 - val_loss: 1.3300 - val_accuracy: 0.5396
# Epoch 82/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3269 - accuracy: 0.5553 - val_loss: 1.3293 - val_accuracy: 0.5601
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3263 - accuracy: 0.5852 - val_loss: 1.3288 - val_accuracy: 0.5440
# Epoch 84/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3257 - accuracy: 0.5574 - val_loss: 1.3281 - val_accuracy: 0.5511
# Epoch 85/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3250 - accuracy: 0.5709 - val_loss: 1.3274 - val_accuracy: 0.5519
# Epoch 86/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3244 - accuracy: 0.5709 - val_loss: 1.3269 - val_accuracy: 0.5496
# Epoch 87/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3237 - accuracy: 0.5535 - val_loss: 1.3261 - val_accuracy: 0.5787
# Epoch 88/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3231 - accuracy: 0.5836 - val_loss: 1.3256 - val_accuracy: 0.5575
# Epoch 89/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3225 - accuracy: 0.5765 - val_loss: 1.3251 - val_accuracy: 0.5556
# Epoch 90/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3218 - accuracy: 0.5774 - val_loss: 1.3245 - val_accuracy: 0.5534
# Epoch 91/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3212 - accuracy: 0.5678 - val_loss: 1.3239 - val_accuracy: 0.5601
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3206 - accuracy: 0.5743 - val_loss: 1.3232 - val_accuracy: 0.5668
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3200 - accuracy: 0.5773 - val_loss: 1.3228 - val_accuracy: 0.5567
# Epoch 94/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3193 - accuracy: 0.5676 - val_loss: 1.3220 - val_accuracy: 0.5675
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3187 - accuracy: 0.5934 - val_loss: 1.3215 - val_accuracy: 0.5444
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3181 - accuracy: 0.5585 - val_loss: 1.3208 - val_accuracy: 0.5646
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3175 - accuracy: 0.5830 - val_loss: 1.3203 - val_accuracy: 0.5534
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3168 - accuracy: 0.5717 - val_loss: 1.3196 - val_accuracy: 0.5623
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3162 - accuracy: 0.5741 - val_loss: 1.3190 - val_accuracy: 0.5728
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3156 - accuracy: 0.5797 - val_loss: 1.3184 - val_accuracy: 0.5716
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3150 - accuracy: 0.5842 - val_loss: 1.3178 - val_accuracy: 0.5705
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3143 - accuracy: 0.5954 - val_loss: 1.3173 - val_accuracy: 0.5575
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3137 - accuracy: 0.5771 - val_loss: 1.3167 - val_accuracy: 0.5646
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3131 - accuracy: 0.5791 - val_loss: 1.3161 - val_accuracy: 0.5683
# Epoch 105/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3125 - accuracy: 0.5716 - val_loss: 1.3155 - val_accuracy: 0.5787
# Epoch 106/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3119 - accuracy: 0.5799 - val_loss: 1.3149 - val_accuracy: 0.5735
# Epoch 107/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3113 - accuracy: 0.5977 - val_loss: 1.3143 - val_accuracy: 0.5761
# Epoch 108/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3107 - accuracy: 0.5837 - val_loss: 1.3138 - val_accuracy: 0.5743
# Epoch 109/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3101 - accuracy: 0.5870 - val_loss: 1.3132 - val_accuracy: 0.5776
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3095 - accuracy: 0.5813 - val_loss: 1.3125 - val_accuracy: 0.5735
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3088 - accuracy: 0.5917 - val_loss: 1.3120 - val_accuracy: 0.5716
# Epoch 112/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3082 - accuracy: 0.5790 - val_loss: 1.3115 - val_accuracy: 0.5649
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3076 - accuracy: 0.5830 - val_loss: 1.3110 - val_accuracy: 0.5701
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3071 - accuracy: 0.5956 - val_loss: 1.3104 - val_accuracy: 0.5638
# Epoch 115/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3065 - accuracy: 0.5851 - val_loss: 1.3099 - val_accuracy: 0.5590
# Epoch 116/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3058 - accuracy: 0.5708 - val_loss: 1.3091 - val_accuracy: 0.5817
# Epoch 117/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3053 - accuracy: 0.5914 - val_loss: 1.3084 - val_accuracy: 0.5869
# Epoch 118/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3047 - accuracy: 0.5963 - val_loss: 1.3080 - val_accuracy: 0.5784
# Epoch 119/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3041 - accuracy: 0.5933 - val_loss: 1.3076 - val_accuracy: 0.5757
# Epoch 120/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3035 - accuracy: 0.5838 - val_loss: 1.3070 - val_accuracy: 0.5687
# Epoch 121/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3029 - accuracy: 0.5971 - val_loss: 1.3064 - val_accuracy: 0.5679
# Epoch 122/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3023 - accuracy: 0.5924 - val_loss: 1.3058 - val_accuracy: 0.5698
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3017 - accuracy: 0.5755 - val_loss: 1.3051 - val_accuracy: 0.5873
# Epoch 124/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3011 - accuracy: 0.5970 - val_loss: 1.3046 - val_accuracy: 0.5821
# Epoch 125/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3005 - accuracy: 0.5793 - val_loss: 1.3041 - val_accuracy: 0.5873
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3000 - accuracy: 0.6077 - val_loss: 1.3036 - val_accuracy: 0.5765
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2994 - accuracy: 0.5941 - val_loss: 1.3030 - val_accuracy: 0.5817
# Epoch 128/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2988 - accuracy: 0.5828 - val_loss: 1.3024 - val_accuracy: 0.5799
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2982 - accuracy: 0.5997 - val_loss: 1.3019 - val_accuracy: 0.5784
# Epoch 130/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2976 - accuracy: 0.5951 - val_loss: 1.3014 - val_accuracy: 0.5776
# Epoch 131/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2971 - accuracy: 0.5917 - val_loss: 1.3009 - val_accuracy: 0.5757
# Epoch 132/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2965 - accuracy: 0.6031 - val_loss: 1.3003 - val_accuracy: 0.5750
# Epoch 133/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2959 - accuracy: 0.5851 - val_loss: 1.2997 - val_accuracy: 0.5757
# Epoch 134/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2953 - accuracy: 0.5925 - val_loss: 1.2991 - val_accuracy: 0.5817
# Epoch 135/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2948 - accuracy: 0.6068 - val_loss: 1.2987 - val_accuracy: 0.5765
# Epoch 136/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2942 - accuracy: 0.5972 - val_loss: 1.2980 - val_accuracy: 0.5799
# Epoch 137/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2936 - accuracy: 0.5994 - val_loss: 1.2975 - val_accuracy: 0.5806
# Epoch 138/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2931 - accuracy: 0.5976 - val_loss: 1.2969 - val_accuracy: 0.5836
# Epoch 139/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2925 - accuracy: 0.5974 - val_loss: 1.2964 - val_accuracy: 0.5869
# Epoch 140/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2919 - accuracy: 0.6013 - val_loss: 1.2960 - val_accuracy: 0.5769
# Epoch 141/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2914 - accuracy: 0.5942 - val_loss: 1.2953 - val_accuracy: 0.5828
# Epoch 142/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2908 - accuracy: 0.5940 - val_loss: 1.2947 - val_accuracy: 0.5828
# Epoch 143/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2902 - accuracy: 0.6036 - val_loss: 1.2942 - val_accuracy: 0.5866
# Epoch 144/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2897 - accuracy: 0.5984 - val_loss: 1.2936 - val_accuracy: 0.5896
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2891 - accuracy: 0.6014 - val_loss: 1.2931 - val_accuracy: 0.5851
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2886 - accuracy: 0.6001 - val_loss: 1.2926 - val_accuracy: 0.5896
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2880 - accuracy: 0.6055 - val_loss: 1.2922 - val_accuracy: 0.5799
# Epoch 148/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2874 - accuracy: 0.5931 - val_loss: 1.2915 - val_accuracy: 0.5873
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2869 - accuracy: 0.5984 - val_loss: 1.2910 - val_accuracy: 0.5918
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2864 - accuracy: 0.6076 - val_loss: 1.2905 - val_accuracy: 0.5869
# 413/413 [==============================] - 1s 2ms/step - loss: 1.2870 - accuracy: 0.6007
#  10%|████████▎                                                                          | 1/10 [08:00<1:12:04, 480.52s/it]
# [1.2870310544967651, 0.6006515622138977]
# 1.0 0.0
# (40000, 1000)
# Epoch 1/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3855 - accuracy: 0.2569 - val_loss: 1.3849 - val_accuracy: 0.2425
# Epoch 2/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3838 - accuracy: 0.2541 - val_loss: 1.3833 - val_accuracy: 0.2425
# Epoch 3/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3821 - accuracy: 0.2561 - val_loss: 1.3817 - val_accuracy: 0.2425
# Epoch 4/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3803 - accuracy: 0.2541 - val_loss: 1.3801 - val_accuracy: 0.2425
# Epoch 5/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3786 - accuracy: 0.2542 - val_loss: 1.3782 - val_accuracy: 0.2425
# Epoch 6/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3769 - accuracy: 0.2833 - val_loss: 1.3765 - val_accuracy: 0.3164
# Epoch 7/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3752 - accuracy: 0.3385 - val_loss: 1.3749 - val_accuracy: 0.4090
# Epoch 8/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3735 - accuracy: 0.3865 - val_loss: 1.3733 - val_accuracy: 0.4265
# Epoch 9/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3718 - accuracy: 0.4860 - val_loss: 1.3715 - val_accuracy: 0.4530
# Epoch 10/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3701 - accuracy: 0.4593 - val_loss: 1.3700 - val_accuracy: 0.4687
# Epoch 11/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3684 - accuracy: 0.5197 - val_loss: 1.3684 - val_accuracy: 0.5604
# Epoch 12/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3667 - accuracy: 0.5124 - val_loss: 1.3668 - val_accuracy: 0.5892
# Epoch 13/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3651 - accuracy: 0.5696 - val_loss: 1.3651 - val_accuracy: 0.5052
# Epoch 14/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3634 - accuracy: 0.5712 - val_loss: 1.3634 - val_accuracy: 0.4634
# Epoch 15/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3617 - accuracy: 0.5182 - val_loss: 1.3618 - val_accuracy: 0.5489
# Epoch 16/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3601 - accuracy: 0.5258 - val_loss: 1.3602 - val_accuracy: 0.6142
# Epoch 17/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3584 - accuracy: 0.5701 - val_loss: 1.3585 - val_accuracy: 0.6160
# Epoch 18/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3568 - accuracy: 0.6141 - val_loss: 1.3569 - val_accuracy: 0.5646
# Epoch 19/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3551 - accuracy: 0.5895 - val_loss: 1.3551 - val_accuracy: 0.5560
# Epoch 20/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3535 - accuracy: 0.5572 - val_loss: 1.3537 - val_accuracy: 0.6123
# Epoch 21/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3519 - accuracy: 0.6059 - val_loss: 1.3521 - val_accuracy: 0.6019
# Epoch 22/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3502 - accuracy: 0.5775 - val_loss: 1.3504 - val_accuracy: 0.5571
# Epoch 23/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3486 - accuracy: 0.6092 - val_loss: 1.3488 - val_accuracy: 0.5526
# Epoch 24/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3470 - accuracy: 0.6016 - val_loss: 1.3472 - val_accuracy: 0.5534
# Epoch 25/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3454 - accuracy: 0.5732 - val_loss: 1.3456 - val_accuracy: 0.5377
# Epoch 26/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3438 - accuracy: 0.6514 - val_loss: 1.3441 - val_accuracy: 0.5235
# Epoch 27/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3422 - accuracy: 0.5616 - val_loss: 1.3426 - val_accuracy: 0.5545
# Epoch 28/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3406 - accuracy: 0.5559 - val_loss: 1.3409 - val_accuracy: 0.5642
# Epoch 29/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3390 - accuracy: 0.6110 - val_loss: 1.3394 - val_accuracy: 0.5567
# Epoch 30/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3374 - accuracy: 0.5942 - val_loss: 1.3379 - val_accuracy: 0.5918
# Epoch 31/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3358 - accuracy: 0.5995 - val_loss: 1.3364 - val_accuracy: 0.5862
# Epoch 32/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3342 - accuracy: 0.6302 - val_loss: 1.3346 - val_accuracy: 0.6187
# Epoch 33/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3327 - accuracy: 0.5534 - val_loss: 1.3332 - val_accuracy: 0.5709
# Epoch 34/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3311 - accuracy: 0.5937 - val_loss: 1.3316 - val_accuracy: 0.5948
# Epoch 35/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3295 - accuracy: 0.6006 - val_loss: 1.3301 - val_accuracy: 0.5597
# Epoch 36/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3280 - accuracy: 0.5659 - val_loss: 1.3287 - val_accuracy: 0.5817
# Epoch 37/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3265 - accuracy: 0.6306 - val_loss: 1.3271 - val_accuracy: 0.5731
# Epoch 38/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3249 - accuracy: 0.5611 - val_loss: 1.3256 - val_accuracy: 0.5638
# Epoch 39/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3234 - accuracy: 0.5995 - val_loss: 1.3242 - val_accuracy: 0.5944
# Epoch 40/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3219 - accuracy: 0.6079 - val_loss: 1.3226 - val_accuracy: 0.5616
# Epoch 41/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3203 - accuracy: 0.5956 - val_loss: 1.3211 - val_accuracy: 0.5701
# Epoch 42/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3188 - accuracy: 0.5888 - val_loss: 1.3196 - val_accuracy: 0.5791
# Epoch 43/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3173 - accuracy: 0.5700 - val_loss: 1.3181 - val_accuracy: 0.5728
# Epoch 44/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3158 - accuracy: 0.6005 - val_loss: 1.3164 - val_accuracy: 0.5974
# Epoch 45/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3143 - accuracy: 0.5817 - val_loss: 1.3149 - val_accuracy: 0.6646
# Epoch 46/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3128 - accuracy: 0.6026 - val_loss: 1.3136 - val_accuracy: 0.5705
# Epoch 47/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3112 - accuracy: 0.6298 - val_loss: 1.3121 - val_accuracy: 0.5470
# Epoch 48/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.3097 - accuracy: 0.5870 - val_loss: 1.3107 - val_accuracy: 0.5496
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3083 - accuracy: 0.5837 - val_loss: 1.3094 - val_accuracy: 0.5638
# Epoch 50/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3067 - accuracy: 0.5895 - val_loss: 1.3077 - val_accuracy: 0.5951
# Epoch 51/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3053 - accuracy: 0.6294 - val_loss: 1.3062 - val_accuracy: 0.5944
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3038 - accuracy: 0.6004 - val_loss: 1.3049 - val_accuracy: 0.5709
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3023 - accuracy: 0.5799 - val_loss: 1.3034 - val_accuracy: 0.6060
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3008 - accuracy: 0.6169 - val_loss: 1.3018 - val_accuracy: 0.6067
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2994 - accuracy: 0.6158 - val_loss: 1.3004 - val_accuracy: 0.5873
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2979 - accuracy: 0.6259 - val_loss: 1.2989 - val_accuracy: 0.6198
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2964 - accuracy: 0.5984 - val_loss: 1.2975 - val_accuracy: 0.6295
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2950 - accuracy: 0.5982 - val_loss: 1.2960 - val_accuracy: 0.6392
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2935 - accuracy: 0.6269 - val_loss: 1.2946 - val_accuracy: 0.6328
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2921 - accuracy: 0.6384 - val_loss: 1.2932 - val_accuracy: 0.6243
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2906 - accuracy: 0.6306 - val_loss: 1.2919 - val_accuracy: 0.6034
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2892 - accuracy: 0.5936 - val_loss: 1.2904 - val_accuracy: 0.6474
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2878 - accuracy: 0.6590 - val_loss: 1.2891 - val_accuracy: 0.5754
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2863 - accuracy: 0.5912 - val_loss: 1.2875 - val_accuracy: 0.6392
# Epoch 65/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2849 - accuracy: 0.6587 - val_loss: 1.2862 - val_accuracy: 0.6067
# Epoch 66/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2835 - accuracy: 0.6140 - val_loss: 1.2848 - val_accuracy: 0.6459
# Epoch 67/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2821 - accuracy: 0.6342 - val_loss: 1.2832 - val_accuracy: 0.6451
# Epoch 68/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2807 - accuracy: 0.6212 - val_loss: 1.2819 - val_accuracy: 0.6381
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2793 - accuracy: 0.6551 - val_loss: 1.2807 - val_accuracy: 0.6261
# Epoch 70/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2779 - accuracy: 0.6292 - val_loss: 1.2793 - val_accuracy: 0.6205
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2764 - accuracy: 0.6507 - val_loss: 1.2780 - val_accuracy: 0.6198
# Epoch 72/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2751 - accuracy: 0.6161 - val_loss: 1.2765 - val_accuracy: 0.6284
# Epoch 73/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2737 - accuracy: 0.6149 - val_loss: 1.2751 - val_accuracy: 0.6448
# Epoch 74/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2723 - accuracy: 0.6684 - val_loss: 1.2738 - val_accuracy: 0.6336
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2709 - accuracy: 0.6251 - val_loss: 1.2725 - val_accuracy: 0.6090
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2695 - accuracy: 0.6576 - val_loss: 1.2712 - val_accuracy: 0.6082
# Epoch 77/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2682 - accuracy: 0.6233 - val_loss: 1.2699 - val_accuracy: 0.5970
# Epoch 78/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2668 - accuracy: 0.6394 - val_loss: 1.2683 - val_accuracy: 0.6388
# Epoch 79/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2654 - accuracy: 0.6209 - val_loss: 1.2670 - val_accuracy: 0.6485
# Epoch 80/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2641 - accuracy: 0.6430 - val_loss: 1.2656 - val_accuracy: 0.6534
# Epoch 81/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2627 - accuracy: 0.6480 - val_loss: 1.2643 - val_accuracy: 0.6515
# Epoch 82/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2613 - accuracy: 0.6527 - val_loss: 1.2630 - val_accuracy: 0.6515
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2600 - accuracy: 0.6625 - val_loss: 1.2617 - val_accuracy: 0.6377
# Epoch 84/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2586 - accuracy: 0.6278 - val_loss: 1.2603 - val_accuracy: 0.6612
# Epoch 85/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2573 - accuracy: 0.6615 - val_loss: 1.2591 - val_accuracy: 0.6276
# Epoch 86/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2559 - accuracy: 0.6438 - val_loss: 1.2577 - val_accuracy: 0.6504
# Epoch 87/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2546 - accuracy: 0.6369 - val_loss: 1.2564 - val_accuracy: 0.6634
# Epoch 88/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2533 - accuracy: 0.6627 - val_loss: 1.2551 - val_accuracy: 0.6455
# Epoch 89/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2519 - accuracy: 0.6667 - val_loss: 1.2537 - val_accuracy: 0.6433
# Epoch 90/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2506 - accuracy: 0.6602 - val_loss: 1.2525 - val_accuracy: 0.6231
# Epoch 91/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2493 - accuracy: 0.6388 - val_loss: 1.2511 - val_accuracy: 0.6537
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2480 - accuracy: 0.6641 - val_loss: 1.2498 - val_accuracy: 0.6422
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2467 - accuracy: 0.6483 - val_loss: 1.2486 - val_accuracy: 0.6478
# Epoch 94/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2453 - accuracy: 0.6511 - val_loss: 1.2472 - val_accuracy: 0.6451
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2440 - accuracy: 0.6584 - val_loss: 1.2460 - val_accuracy: 0.6407
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2428 - accuracy: 0.6624 - val_loss: 1.2447 - val_accuracy: 0.6459
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2414 - accuracy: 0.6571 - val_loss: 1.2435 - val_accuracy: 0.6519
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2402 - accuracy: 0.6440 - val_loss: 1.2422 - val_accuracy: 0.6481
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2389 - accuracy: 0.6621 - val_loss: 1.2409 - val_accuracy: 0.6545
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2376 - accuracy: 0.6618 - val_loss: 1.2397 - val_accuracy: 0.6459
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2363 - accuracy: 0.6596 - val_loss: 1.2384 - val_accuracy: 0.6362
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2350 - accuracy: 0.6423 - val_loss: 1.2371 - val_accuracy: 0.6552
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2337 - accuracy: 0.6712 - val_loss: 1.2359 - val_accuracy: 0.6451
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2325 - accuracy: 0.6650 - val_loss: 1.2348 - val_accuracy: 0.6201
# Epoch 105/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2312 - accuracy: 0.6414 - val_loss: 1.2333 - val_accuracy: 0.6556
# Epoch 106/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2300 - accuracy: 0.6528 - val_loss: 1.2321 - val_accuracy: 0.6519
# Epoch 107/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2287 - accuracy: 0.6684 - val_loss: 1.2309 - val_accuracy: 0.6429
# Epoch 108/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2274 - accuracy: 0.6524 - val_loss: 1.2297 - val_accuracy: 0.6466
# Epoch 109/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2262 - accuracy: 0.6580 - val_loss: 1.2285 - val_accuracy: 0.6507
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2249 - accuracy: 0.6685 - val_loss: 1.2273 - val_accuracy: 0.6560
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2237 - accuracy: 0.6706 - val_loss: 1.2260 - val_accuracy: 0.6534
# Epoch 112/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2225 - accuracy: 0.6530 - val_loss: 1.2247 - val_accuracy: 0.6575
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2212 - accuracy: 0.6677 - val_loss: 1.2235 - val_accuracy: 0.6545
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2200 - accuracy: 0.6576 - val_loss: 1.2222 - val_accuracy: 0.6593
# Epoch 115/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2188 - accuracy: 0.6711 - val_loss: 1.2211 - val_accuracy: 0.6608
# Epoch 116/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2176 - accuracy: 0.6736 - val_loss: 1.2200 - val_accuracy: 0.6571
# Epoch 117/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2163 - accuracy: 0.6689 - val_loss: 1.2187 - val_accuracy: 0.6560
# Epoch 118/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2151 - accuracy: 0.6697 - val_loss: 1.2176 - val_accuracy: 0.6578
# Epoch 119/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2139 - accuracy: 0.6819 - val_loss: 1.2164 - val_accuracy: 0.6511
# Epoch 120/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.2127 - accuracy: 0.6546 - val_loss: 1.2153 - val_accuracy: 0.6586
# Epoch 121/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2115 - accuracy: 0.6682 - val_loss: 1.2141 - val_accuracy: 0.6448
# Epoch 122/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2103 - accuracy: 0.6655 - val_loss: 1.2127 - val_accuracy: 0.6716
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2091 - accuracy: 0.6727 - val_loss: 1.2116 - val_accuracy: 0.6675
# Epoch 124/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.2079 - accuracy: 0.6766 - val_loss: 1.2105 - val_accuracy: 0.6642
# Epoch 125/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2067 - accuracy: 0.6750 - val_loss: 1.2094 - val_accuracy: 0.6530
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2055 - accuracy: 0.6663 - val_loss: 1.2080 - val_accuracy: 0.6709
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2043 - accuracy: 0.6665 - val_loss: 1.2068 - val_accuracy: 0.6687
# Epoch 128/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2031 - accuracy: 0.6781 - val_loss: 1.2058 - val_accuracy: 0.6549
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2020 - accuracy: 0.6703 - val_loss: 1.2047 - val_accuracy: 0.6440
# Epoch 130/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2008 - accuracy: 0.6571 - val_loss: 1.2033 - val_accuracy: 0.6705
# Epoch 131/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1996 - accuracy: 0.6806 - val_loss: 1.2022 - val_accuracy: 0.6713
# Epoch 132/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1984 - accuracy: 0.6783 - val_loss: 1.2011 - val_accuracy: 0.6593
# Epoch 133/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.1973 - accuracy: 0.6730 - val_loss: 1.1999 - val_accuracy: 0.6672
# Epoch 134/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.1961 - accuracy: 0.6792 - val_loss: 1.1989 - val_accuracy: 0.6612
# Epoch 135/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1949 - accuracy: 0.6804 - val_loss: 1.1977 - val_accuracy: 0.6627
# Epoch 136/150
# 189/189 [==============================] - 1s 3ms/step - loss: 1.1938 - accuracy: 0.6678 - val_loss: 1.1965 - val_accuracy: 0.6746
# Epoch 137/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1926 - accuracy: 0.6815 - val_loss: 1.1954 - val_accuracy: 0.6675
# Epoch 138/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1915 - accuracy: 0.6774 - val_loss: 1.1942 - val_accuracy: 0.6728
# Epoch 139/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1904 - accuracy: 0.6817 - val_loss: 1.1931 - val_accuracy: 0.6728
# Epoch 140/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1892 - accuracy: 0.6763 - val_loss: 1.1921 - val_accuracy: 0.6616
# Epoch 141/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1881 - accuracy: 0.6773 - val_loss: 1.1910 - val_accuracy: 0.6612
# Epoch 142/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1869 - accuracy: 0.6818 - val_loss: 1.1899 - val_accuracy: 0.6601
# Epoch 143/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1858 - accuracy: 0.6682 - val_loss: 1.1886 - val_accuracy: 0.6728
# Epoch 144/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1847 - accuracy: 0.6850 - val_loss: 1.1875 - val_accuracy: 0.6698
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1836 - accuracy: 0.6777 - val_loss: 1.1866 - val_accuracy: 0.6623
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1825 - accuracy: 0.6712 - val_loss: 1.1853 - val_accuracy: 0.6776
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1813 - accuracy: 0.6812 - val_loss: 1.1842 - val_accuracy: 0.6743
# Epoch 148/150
# 189/189 [==============================] - 0s 3ms/step - loss: 1.1802 - accuracy: 0.6834 - val_loss: 1.1831 - val_accuracy: 0.6646
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1791 - accuracy: 0.6734 - val_loss: 1.1821 - val_accuracy: 0.6660
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1780 - accuracy: 0.6905 - val_loss: 1.1809 - val_accuracy: 0.6668
# 413/413 [==============================] - 1s 2ms/step - loss: 1.1750 - accuracy: 0.6850
#  20%|████████████████▌                                                                  | 2/10 [16:44<1:07:27, 505.91s/it]
# [1.1750434637069702, 0.6849761605262756]
# ...
# Epoch 42/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3253 - accuracy: 0.5612 - val_loss: 1.3252 - val_accuracy: 0.5694
# Epoch 43/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3239 - accuracy: 0.5621 - val_loss: 1.3239 - val_accuracy: 0.6134
# Epoch 44/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3226 - accuracy: 0.5874 - val_loss: 1.3226 - val_accuracy: 0.5892
# Epoch 45/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3212 - accuracy: 0.6056 - val_loss: 1.3213 - val_accuracy: 0.5366
# Epoch 46/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3199 - accuracy: 0.5763 - val_loss: 1.3198 - val_accuracy: 0.5687
# Epoch 47/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3185 - accuracy: 0.5366 - val_loss: 1.3185 - val_accuracy: 0.5881
# Epoch 48/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3172 - accuracy: 0.5911 - val_loss: 1.3171 - val_accuracy: 0.5866
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3158 - accuracy: 0.5713 - val_loss: 1.3158 - val_accuracy: 0.6183
# Epoch 50/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3145 - accuracy: 0.6048 - val_loss: 1.3146 - val_accuracy: 0.5784
# Epoch 51/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3132 - accuracy: 0.5810 - val_loss: 1.3132 - val_accuracy: 0.5989
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3118 - accuracy: 0.5738 - val_loss: 1.3119 - val_accuracy: 0.5910
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3105 - accuracy: 0.6051 - val_loss: 1.3105 - val_accuracy: 0.5914
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3092 - accuracy: 0.5804 - val_loss: 1.3092 - val_accuracy: 0.6149
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3079 - accuracy: 0.5896 - val_loss: 1.3077 - val_accuracy: 0.6157
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3066 - accuracy: 0.6031 - val_loss: 1.3065 - val_accuracy: 0.6004
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3053 - accuracy: 0.5893 - val_loss: 1.3053 - val_accuracy: 0.5989
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3040 - accuracy: 0.5857 - val_loss: 1.3040 - val_accuracy: 0.6179
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3027 - accuracy: 0.6317 - val_loss: 1.3026 - val_accuracy: 0.5806
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3014 - accuracy: 0.5474 - val_loss: 1.3014 - val_accuracy: 0.6250
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3001 - accuracy: 0.6179 - val_loss: 1.3001 - val_accuracy: 0.6146
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2989 - accuracy: 0.5866 - val_loss: 1.2988 - val_accuracy: 0.6246
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2976 - accuracy: 0.6067 - val_loss: 1.2976 - val_accuracy: 0.6209
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2963 - accuracy: 0.6071 - val_loss: 1.2963 - val_accuracy: 0.6373
# Epoch 65/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2950 - accuracy: 0.6072 - val_loss: 1.2951 - val_accuracy: 0.6239
# Epoch 66/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2937 - accuracy: 0.6030 - val_loss: 1.2939 - val_accuracy: 0.6224
# Epoch 67/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2925 - accuracy: 0.6162 - val_loss: 1.2925 - val_accuracy: 0.6090
# Epoch 68/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2912 - accuracy: 0.6080 - val_loss: 1.2913 - val_accuracy: 0.6231
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2900 - accuracy: 0.6126 - val_loss: 1.2901 - val_accuracy: 0.5933
# Epoch 70/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2887 - accuracy: 0.6034 - val_loss: 1.2889 - val_accuracy: 0.6138
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2875 - accuracy: 0.6116 - val_loss: 1.2875 - val_accuracy: 0.6228
# Epoch 72/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2862 - accuracy: 0.6141 - val_loss: 1.2864 - val_accuracy: 0.6209
# Epoch 73/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2850 - accuracy: 0.6119 - val_loss: 1.2850 - val_accuracy: 0.6216
# Epoch 74/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2838 - accuracy: 0.6120 - val_loss: 1.2838 - val_accuracy: 0.6112
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2825 - accuracy: 0.6080 - val_loss: 1.2826 - val_accuracy: 0.6299
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2813 - accuracy: 0.6337 - val_loss: 1.2814 - val_accuracy: 0.6175
# Epoch 77/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2801 - accuracy: 0.6164 - val_loss: 1.2802 - val_accuracy: 0.6090
# Epoch 78/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2789 - accuracy: 0.6069 - val_loss: 1.2791 - val_accuracy: 0.6265
# Epoch 79/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2777 - accuracy: 0.6132 - val_loss: 1.2779 - val_accuracy: 0.6328
# Epoch 80/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2765 - accuracy: 0.6362 - val_loss: 1.2767 - val_accuracy: 0.6209
# Epoch 81/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2753 - accuracy: 0.6034 - val_loss: 1.2755 - val_accuracy: 0.6284
# Epoch 82/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2741 - accuracy: 0.6360 - val_loss: 1.2743 - val_accuracy: 0.6104
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2729 - accuracy: 0.6177 - val_loss: 1.2731 - val_accuracy: 0.6179
# Epoch 84/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2717 - accuracy: 0.6060 - val_loss: 1.2718 - val_accuracy: 0.6310
# Epoch 85/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2705 - accuracy: 0.6051 - val_loss: 1.2706 - val_accuracy: 0.6396
# Epoch 86/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2694 - accuracy: 0.6348 - val_loss: 1.2695 - val_accuracy: 0.6366
# Epoch 87/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2682 - accuracy: 0.6361 - val_loss: 1.2684 - val_accuracy: 0.6257
# Epoch 88/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2670 - accuracy: 0.6276 - val_loss: 1.2672 - val_accuracy: 0.6265
# Epoch 89/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2659 - accuracy: 0.6152 - val_loss: 1.2661 - val_accuracy: 0.6313
# Epoch 90/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2647 - accuracy: 0.6383 - val_loss: 1.2648 - val_accuracy: 0.6291
# Epoch 91/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2636 - accuracy: 0.6190 - val_loss: 1.2635 - val_accuracy: 0.6343
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2624 - accuracy: 0.6236 - val_loss: 1.2625 - val_accuracy: 0.6425
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2612 - accuracy: 0.6342 - val_loss: 1.2614 - val_accuracy: 0.6358
# Epoch 94/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2601 - accuracy: 0.6279 - val_loss: 1.2603 - val_accuracy: 0.6377
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2590 - accuracy: 0.6297 - val_loss: 1.2591 - val_accuracy: 0.6343
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2578 - accuracy: 0.6281 - val_loss: 1.2580 - val_accuracy: 0.6336
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2567 - accuracy: 0.6324 - val_loss: 1.2569 - val_accuracy: 0.6354
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2555 - accuracy: 0.6283 - val_loss: 1.2558 - val_accuracy: 0.6287
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2544 - accuracy: 0.6290 - val_loss: 1.2547 - val_accuracy: 0.6362
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2533 - accuracy: 0.6376 - val_loss: 1.2535 - val_accuracy: 0.6239
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2521 - accuracy: 0.6315 - val_loss: 1.2523 - val_accuracy: 0.6313
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2510 - accuracy: 0.6199 - val_loss: 1.2512 - val_accuracy: 0.6466
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2499 - accuracy: 0.6423 - val_loss: 1.2501 - val_accuracy: 0.6407
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2488 - accuracy: 0.6345 - val_loss: 1.2489 - val_accuracy: 0.6437
# Epoch 105/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2477 - accuracy: 0.6303 - val_loss: 1.2478 - val_accuracy: 0.6463
# Epoch 106/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2465 - accuracy: 0.6380 - val_loss: 1.2468 - val_accuracy: 0.6515
# Epoch 107/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2455 - accuracy: 0.6365 - val_loss: 1.2458 - val_accuracy: 0.6388
# Epoch 108/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2444 - accuracy: 0.6509 - val_loss: 1.2447 - val_accuracy: 0.6328
# Epoch 109/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2433 - accuracy: 0.6349 - val_loss: 1.2436 - val_accuracy: 0.6295
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2422 - accuracy: 0.6339 - val_loss: 1.2424 - val_accuracy: 0.6347
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2411 - accuracy: 0.6325 - val_loss: 1.2411 - val_accuracy: 0.6504
# Epoch 112/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2400 - accuracy: 0.6410 - val_loss: 1.2403 - val_accuracy: 0.6418
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2389 - accuracy: 0.6295 - val_loss: 1.2393 - val_accuracy: 0.6500
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2379 - accuracy: 0.6500 - val_loss: 1.2381 - val_accuracy: 0.6470
# Epoch 115/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2368 - accuracy: 0.6439 - val_loss: 1.2371 - val_accuracy: 0.6470
# Epoch 116/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2357 - accuracy: 0.6414 - val_loss: 1.2360 - val_accuracy: 0.6425
# Epoch 117/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2347 - accuracy: 0.6530 - val_loss: 1.2351 - val_accuracy: 0.6399
# Epoch 118/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2336 - accuracy: 0.6371 - val_loss: 1.2338 - val_accuracy: 0.6478
# Epoch 119/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2325 - accuracy: 0.6342 - val_loss: 1.2328 - val_accuracy: 0.6526
# Epoch 120/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2315 - accuracy: 0.6413 - val_loss: 1.2317 - val_accuracy: 0.6664
# Epoch 121/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2304 - accuracy: 0.6562 - val_loss: 1.2306 - val_accuracy: 0.6455
# Epoch 122/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2293 - accuracy: 0.6386 - val_loss: 1.2296 - val_accuracy: 0.6575
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2283 - accuracy: 0.6484 - val_loss: 1.2286 - val_accuracy: 0.6586
# Epoch 124/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2273 - accuracy: 0.6502 - val_loss: 1.2275 - val_accuracy: 0.6534
# Epoch 125/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2262 - accuracy: 0.6420 - val_loss: 1.2266 - val_accuracy: 0.6616
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2252 - accuracy: 0.6480 - val_loss: 1.2254 - val_accuracy: 0.6612
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2242 - accuracy: 0.6495 - val_loss: 1.2245 - val_accuracy: 0.6608
# Epoch 128/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2231 - accuracy: 0.6438 - val_loss: 1.2235 - val_accuracy: 0.6504
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2221 - accuracy: 0.6489 - val_loss: 1.2222 - val_accuracy: 0.6608
# Epoch 130/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2210 - accuracy: 0.6580 - val_loss: 1.2215 - val_accuracy: 0.6582
# Epoch 131/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2200 - accuracy: 0.6354 - val_loss: 1.2202 - val_accuracy: 0.6646
# Epoch 132/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2190 - accuracy: 0.6584 - val_loss: 1.2193 - val_accuracy: 0.6563
# Epoch 133/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2179 - accuracy: 0.6581 - val_loss: 1.2183 - val_accuracy: 0.6522
# Epoch 134/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2169 - accuracy: 0.6579 - val_loss: 1.2173 - val_accuracy: 0.6515
# Epoch 135/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2159 - accuracy: 0.6377 - val_loss: 1.2162 - val_accuracy: 0.6545
# Epoch 136/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2149 - accuracy: 0.6510 - val_loss: 1.2152 - val_accuracy: 0.6683
# Epoch 137/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2139 - accuracy: 0.6631 - val_loss: 1.2142 - val_accuracy: 0.6619
# Epoch 138/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2129 - accuracy: 0.6521 - val_loss: 1.2134 - val_accuracy: 0.6623
# Epoch 139/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2119 - accuracy: 0.6582 - val_loss: 1.2125 - val_accuracy: 0.6638
# Epoch 140/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2109 - accuracy: 0.6549 - val_loss: 1.2113 - val_accuracy: 0.6537
# Epoch 141/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2099 - accuracy: 0.6522 - val_loss: 1.2104 - val_accuracy: 0.6586
# Epoch 142/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2089 - accuracy: 0.6604 - val_loss: 1.2094 - val_accuracy: 0.6649
# Epoch 143/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2079 - accuracy: 0.6446 - val_loss: 1.2083 - val_accuracy: 0.6679
# Epoch 144/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2069 - accuracy: 0.6657 - val_loss: 1.2073 - val_accuracy: 0.6660
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2059 - accuracy: 0.6568 - val_loss: 1.2064 - val_accuracy: 0.6604
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2049 - accuracy: 0.6587 - val_loss: 1.2055 - val_accuracy: 0.6690
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2039 - accuracy: 0.6608 - val_loss: 1.2043 - val_accuracy: 0.6657
# Epoch 148/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2029 - accuracy: 0.6598 - val_loss: 1.2034 - val_accuracy: 0.6646
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2020 - accuracy: 0.6675 - val_loss: 1.2024 - val_accuracy: 0.6522
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2010 - accuracy: 0.6510 - val_loss: 1.2013 - val_accuracy: 0.6687
# 413/413 [==============================] - 1s 1ms/step - loss: 1.2038 - accuracy: 0.6647
# 100%|████████████████████████████████████████████████████████████████████████████████████| 10/10 [57:39<00:00, 345.97s/it]
# [1.2038120031356812, 0.6646715402603149]

# %%
print(np.mean(total_scores))
print(np.std(total_scores))
# Out:
# 0.6612546443939209
# 0.06619925734983738
