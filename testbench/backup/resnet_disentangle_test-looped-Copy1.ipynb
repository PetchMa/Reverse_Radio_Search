# %%
import numpy as np
import setigen as stg
from blimpy import Waterfall
import matplotlib.pyplot as plt
import random
import os
from astropy import units as u
from tqdm import tqdm
from sklearn.metrics import silhouette_score
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers

os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# 2023-05-28 17:25:23.049064: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def painting(data):
    all_data = []
    labels = []
    for c in range(num_classes):
        drift = 2*random.random()*(-1)**random.randint(0,2)
        snr = random.randint(100, 150)
        width = random.randint(20, 50)
        for s in range(num_samples_per_class):
            index = random.randint(0, data.shape[0]-1)
            window = data[index, :,:]
            
            start = random.randint(50, 180)
            
            frame = stg.Frame.from_data(df=2.7939677238464355*u.Hz,
                                        dt=18.253611008*u.s,
                                        fch1=1289*u.MHz,
                                        ascending=True,
                                        data=window)
            frame.add_signal(stg.constant_path(
                                        f_start=frame.get_frequency(index=start),
                                       drift_rate=drift*u.Hz/u.s),
                                      stg.constant_t_profile(level=frame.get_intensity(snr=snr)),
                                      stg.gaussian_f_profile(width=width*u.Hz),
                                      stg.constant_bp_profile(level=1))
            all_data.append(frame.data)
            labels.append(c)
    all_data = np.array(all_data)
    labels = np.vstack(labels)
    return all_data, labels

# %%
import cv2
import numpy as np

def transform(data):
    final = []
    for i in range(data.shape[0]):
        img = np.repeat(data[i,:, :], 3, axis=2)
        res = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
        final.append(res)
    return np.array(final)

# %%
from tqdm import tqdm
import gc

def normalize(data):
    epsilon = 1
    min_val = data.min()
    data = data - min_val + epsilon
    new_data = np.log(data)
    min_val = data.min()
    max_val = data.max()
    final_data = (data - min_val) / (max_val - min_val)
    return final_data
    
def normalize_data(data):
    for i in range(data.shape[0]):
        data[i,:,:] = normalize(data[i,:,:, :])
    return data

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras import Model

model = ResNet50(include_top=True,
                weights='imagenet',
                input_tensor=None,
                input_shape=None,
                pooling=None,
                classes=1000
                )
truncated_model = Model(inputs = model.layers[0].input, outputs = model.layers[-1].output)
truncated_model.summary()
truncated_model.compile(optimizer='rmsprop')
# Out:
# 2023-05-28 17:25:29.507206: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-28 17:25:29.866745: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14233 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  2D)
#
#  predictions (Dense)            (None, 1000)         2049000     ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
def idealized(num=10_000):
    drift = 0
    snr = 20
    width = 10
    start = 256//2
    data = []
    labels = []
    for tag in range(4):
        label_vec = np.zeros(4)
        label_vec[tag] = 1
        for i in range(num):
            if tag == 0:
                drift = (-1)**(random.randint(0,2)) * 2 *random.random()
            elif tag == 1:
                snr = 50*random.random() +20
            elif tag == 2:
                width = 50*random.random() +20
            elif tag == 3:
                start = random.randint(50, 180)

            frame = stg.Frame(fchans=256*u.pixel,
                              tchans=16*u.pixel,
                              df=2.7939677238464355*u.Hz,
                              dt=18.253611008*u.s,
                              fch1=6095.214842353016*u.MHz)
            noise = frame.add_noise(x_mean=10, noise_type='chi2')
            frame.add_signal(stg.constant_path(
                                        f_start=frame.get_frequency(index=start),
                                       drift_rate=drift*u.Hz/u.s),
                                      stg.constant_t_profile(level=frame.get_intensity(snr=snr)),
                                      stg.gaussian_f_profile(width=width*u.Hz),
                                      stg.constant_bp_profile(level=1))
            data.append(frame.data)
            labels.append(label_vec)
    data = np.array(data)
    labels = np.vstack(labels)
    return data, labels

# %%
import os
from tqdm import tqdm
import keras
total_scores = []
for i in tqdm(range(10)):
    idealized_signals, labels = idealized(num = 10_000)

    input_data = transform(np.expand_dims(idealized_signals, axis = -1))
    gc.collect()
    input_data = normalize_data(input_data)
    print(input_data[0,:,:].max(), input_data[0,:,:].min())
    splits = input_data.shape[0]//1_000
    X = []
    for i in range(splits):
        tensor = tf.convert_to_tensor(input_data[i*1_000:(i+1)*1_000, :,:,:], dtype=tf.float32)
        X.append(truncated_model(tensor))
    X = np.vstack(X)
    print(X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.33, random_state=42)

    linear = keras.Sequential(name="my_sequential")
    # linear.add(layers.Dense(1000, activation="linear", name="layer1"))
    linear.add(layers.Dense(4, activation="softmax", name="layer2"))

    linear.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    linear.fit(X_train, y_train, epochs=150, batch_size=128, validation_split = 0.1, shuffle=True)
    results = linear.evaluate(X_test, y_test)
    print(results)
    total_scores.append(results[-1])
# Out:
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# 1.0 0.0
# 2023-05-28 17:28:02.460324: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-05-28 17:28:03.516960: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:03.517028: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.88GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:03.642134: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:03.642161: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:03.642177: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:03.642191: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:04.328476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-05-28 17:28:07.395896: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:07.395988: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:07.489715: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-05-28 17:28:07.489747: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.01GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# (40000, 1000)
# Epoch 1/150
# 2023-05-28 17:29:09.318031: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f48c80172f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-28 17:29:09.318141: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2023-05-28 17:29:09.325746: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-05-28 17:29:09.510158: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 189/189 [==============================] - 1s 3ms/step - loss: 1.3850 - accuracy: 0.2924 - val_loss: 1.3840 - val_accuracy: 0.2377
# Epoch 2/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3825 - accuracy: 0.3054 - val_loss: 1.3818 - val_accuracy: 0.2448
# Epoch 3/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3801 - accuracy: 0.3515 - val_loss: 1.3794 - val_accuracy: 0.4791
# Epoch 4/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3776 - accuracy: 0.4920 - val_loss: 1.3771 - val_accuracy: 0.4791
# Epoch 5/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3752 - accuracy: 0.4690 - val_loss: 1.3745 - val_accuracy: 0.5299
# Epoch 6/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3727 - accuracy: 0.5395 - val_loss: 1.3717 - val_accuracy: 0.6765
# Epoch 7/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3702 - accuracy: 0.5865 - val_loss: 1.3693 - val_accuracy: 0.5937
# Epoch 8/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3677 - accuracy: 0.5782 - val_loss: 1.3666 - val_accuracy: 0.6978
# Epoch 9/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3653 - accuracy: 0.6187 - val_loss: 1.3645 - val_accuracy: 0.6813
# Epoch 10/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3628 - accuracy: 0.6774 - val_loss: 1.3621 - val_accuracy: 0.6862
# Epoch 11/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3604 - accuracy: 0.6652 - val_loss: 1.3594 - val_accuracy: 0.7127
# Epoch 12/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3580 - accuracy: 0.6638 - val_loss: 1.3571 - val_accuracy: 0.6937
# Epoch 13/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3557 - accuracy: 0.6893 - val_loss: 1.3548 - val_accuracy: 0.6701
# Epoch 14/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3532 - accuracy: 0.7258 - val_loss: 1.3525 - val_accuracy: 0.6772
# Epoch 15/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3509 - accuracy: 0.7147 - val_loss: 1.3506 - val_accuracy: 0.6444
# Epoch 16/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3485 - accuracy: 0.6852 - val_loss: 1.3476 - val_accuracy: 0.7119
# Epoch 17/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3461 - accuracy: 0.7134 - val_loss: 1.3456 - val_accuracy: 0.6575
# Epoch 18/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3438 - accuracy: 0.6884 - val_loss: 1.3430 - val_accuracy: 0.6795
# Epoch 19/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3415 - accuracy: 0.7144 - val_loss: 1.3406 - val_accuracy: 0.7243
# Epoch 20/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3392 - accuracy: 0.7225 - val_loss: 1.3384 - val_accuracy: 0.7112
# Epoch 21/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3368 - accuracy: 0.7226 - val_loss: 1.3360 - val_accuracy: 0.7067
# Epoch 22/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3345 - accuracy: 0.7309 - val_loss: 1.3339 - val_accuracy: 0.6910
# Epoch 23/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3322 - accuracy: 0.7434 - val_loss: 1.3319 - val_accuracy: 0.6955
# Epoch 24/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3300 - accuracy: 0.7063 - val_loss: 1.3294 - val_accuracy: 0.7007
# Epoch 25/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3276 - accuracy: 0.7196 - val_loss: 1.3272 - val_accuracy: 0.6970
# Epoch 26/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3253 - accuracy: 0.7201 - val_loss: 1.3245 - val_accuracy: 0.7022
# Epoch 27/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3230 - accuracy: 0.7156 - val_loss: 1.3220 - val_accuracy: 0.7336
# Epoch 28/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3207 - accuracy: 0.7418 - val_loss: 1.3201 - val_accuracy: 0.7104
# Epoch 29/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3185 - accuracy: 0.7133 - val_loss: 1.3178 - val_accuracy: 0.7530
# Epoch 30/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3162 - accuracy: 0.7335 - val_loss: 1.3153 - val_accuracy: 0.7082
# Epoch 31/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3140 - accuracy: 0.7225 - val_loss: 1.3133 - val_accuracy: 0.7246
# Epoch 32/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3118 - accuracy: 0.7312 - val_loss: 1.3114 - val_accuracy: 0.6922
# Epoch 33/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3096 - accuracy: 0.7221 - val_loss: 1.3088 - val_accuracy: 0.7310
# Epoch 34/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3074 - accuracy: 0.7286 - val_loss: 1.3067 - val_accuracy: 0.7313
# Epoch 35/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3052 - accuracy: 0.7218 - val_loss: 1.3046 - val_accuracy: 0.7313
# Epoch 36/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3029 - accuracy: 0.7469 - val_loss: 1.3026 - val_accuracy: 0.6948
# Epoch 37/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3008 - accuracy: 0.7262 - val_loss: 1.3005 - val_accuracy: 0.6978
# Epoch 38/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2986 - accuracy: 0.7319 - val_loss: 1.2982 - val_accuracy: 0.6996
# Epoch 39/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2964 - accuracy: 0.7133 - val_loss: 1.2962 - val_accuracy: 0.7243
# Epoch 40/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2943 - accuracy: 0.7351 - val_loss: 1.2942 - val_accuracy: 0.6888
# Epoch 41/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2921 - accuracy: 0.7376 - val_loss: 1.2922 - val_accuracy: 0.6866
# Epoch 42/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2900 - accuracy: 0.7307 - val_loss: 1.2897 - val_accuracy: 0.6735
# Epoch 43/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2878 - accuracy: 0.7142 - val_loss: 1.2874 - val_accuracy: 0.7243
# Epoch 44/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2857 - accuracy: 0.7211 - val_loss: 1.2852 - val_accuracy: 0.7269
# Epoch 45/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2835 - accuracy: 0.7388 - val_loss: 1.2834 - val_accuracy: 0.6970
# Epoch 46/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2814 - accuracy: 0.7199 - val_loss: 1.2808 - val_accuracy: 0.7257
# Epoch 47/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2793 - accuracy: 0.7321 - val_loss: 1.2790 - val_accuracy: 0.7123
# Epoch 48/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2772 - accuracy: 0.7232 - val_loss: 1.2766 - val_accuracy: 0.7257
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2751 - accuracy: 0.7385 - val_loss: 1.2750 - val_accuracy: 0.6881
# Epoch 50/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2730 - accuracy: 0.7235 - val_loss: 1.2729 - val_accuracy: 0.7101
# Epoch 51/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2709 - accuracy: 0.7231 - val_loss: 1.2711 - val_accuracy: 0.7037
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2689 - accuracy: 0.7340 - val_loss: 1.2688 - val_accuracy: 0.7071
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2668 - accuracy: 0.7256 - val_loss: 1.2664 - val_accuracy: 0.7187
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2648 - accuracy: 0.7346 - val_loss: 1.2646 - val_accuracy: 0.7026
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2627 - accuracy: 0.7197 - val_loss: 1.2629 - val_accuracy: 0.7037
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2606 - accuracy: 0.7296 - val_loss: 1.2605 - val_accuracy: 0.7134
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2586 - accuracy: 0.7250 - val_loss: 1.2584 - val_accuracy: 0.7243
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2566 - accuracy: 0.7312 - val_loss: 1.2567 - val_accuracy: 0.7112
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2545 - accuracy: 0.7351 - val_loss: 1.2541 - val_accuracy: 0.7119
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2525 - accuracy: 0.7247 - val_loss: 1.2526 - val_accuracy: 0.7097
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2505 - accuracy: 0.7264 - val_loss: 1.2503 - val_accuracy: 0.7216
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2485 - accuracy: 0.7316 - val_loss: 1.2484 - val_accuracy: 0.7123
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2464 - accuracy: 0.7214 - val_loss: 1.2462 - val_accuracy: 0.7287
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2444 - accuracy: 0.7405 - val_loss: 1.2445 - val_accuracy: 0.6933
# Epoch 65/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2424 - accuracy: 0.7296 - val_loss: 1.2425 - val_accuracy: 0.7093
# Epoch 66/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2405 - accuracy: 0.7364 - val_loss: 1.2405 - val_accuracy: 0.7041
# Epoch 67/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2385 - accuracy: 0.7161 - val_loss: 1.2385 - val_accuracy: 0.7354
# Epoch 68/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2366 - accuracy: 0.7386 - val_loss: 1.2365 - val_accuracy: 0.7194
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2346 - accuracy: 0.7230 - val_loss: 1.2346 - val_accuracy: 0.7302
# Epoch 70/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2326 - accuracy: 0.7426 - val_loss: 1.2331 - val_accuracy: 0.6918
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2307 - accuracy: 0.7265 - val_loss: 1.2307 - val_accuracy: 0.7090
# Epoch 72/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2287 - accuracy: 0.7262 - val_loss: 1.2286 - val_accuracy: 0.7254
# Epoch 73/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2268 - accuracy: 0.7438 - val_loss: 1.2272 - val_accuracy: 0.6888
# Epoch 74/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2248 - accuracy: 0.7022 - val_loss: 1.2247 - val_accuracy: 0.7317
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2230 - accuracy: 0.7505 - val_loss: 1.2229 - val_accuracy: 0.7086
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2211 - accuracy: 0.7285 - val_loss: 1.2214 - val_accuracy: 0.7034
# Epoch 77/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2192 - accuracy: 0.7293 - val_loss: 1.2196 - val_accuracy: 0.7213
# Epoch 78/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2173 - accuracy: 0.7417 - val_loss: 1.2178 - val_accuracy: 0.7000
# Epoch 79/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2154 - accuracy: 0.7326 - val_loss: 1.2157 - val_accuracy: 0.7146
# Epoch 80/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2136 - accuracy: 0.7225 - val_loss: 1.2138 - val_accuracy: 0.7187
# Epoch 81/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2117 - accuracy: 0.7376 - val_loss: 1.2119 - val_accuracy: 0.7071
# Epoch 82/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2098 - accuracy: 0.7318 - val_loss: 1.2101 - val_accuracy: 0.7164
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2079 - accuracy: 0.7429 - val_loss: 1.2081 - val_accuracy: 0.7086
# Epoch 84/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2061 - accuracy: 0.7222 - val_loss: 1.2063 - val_accuracy: 0.7205
# Epoch 85/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2043 - accuracy: 0.7385 - val_loss: 1.2046 - val_accuracy: 0.7172
# Epoch 86/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2024 - accuracy: 0.7291 - val_loss: 1.2029 - val_accuracy: 0.7284
# Epoch 87/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2005 - accuracy: 0.7342 - val_loss: 1.2011 - val_accuracy: 0.7287
# Epoch 88/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1987 - accuracy: 0.7379 - val_loss: 1.1990 - val_accuracy: 0.7261
# Epoch 89/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1969 - accuracy: 0.7334 - val_loss: 1.1971 - val_accuracy: 0.7343
# Epoch 90/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1951 - accuracy: 0.7426 - val_loss: 1.1956 - val_accuracy: 0.7160
# Epoch 91/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1933 - accuracy: 0.7386 - val_loss: 1.1940 - val_accuracy: 0.7138
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1915 - accuracy: 0.7335 - val_loss: 1.1923 - val_accuracy: 0.7168
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1898 - accuracy: 0.7307 - val_loss: 1.1904 - val_accuracy: 0.7246
# Epoch 94/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1880 - accuracy: 0.7432 - val_loss: 1.1886 - val_accuracy: 0.7123
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1862 - accuracy: 0.7296 - val_loss: 1.1871 - val_accuracy: 0.7257
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1845 - accuracy: 0.7394 - val_loss: 1.1849 - val_accuracy: 0.7194
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1828 - accuracy: 0.7318 - val_loss: 1.1831 - val_accuracy: 0.7295
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1810 - accuracy: 0.7434 - val_loss: 1.1817 - val_accuracy: 0.7164
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1793 - accuracy: 0.7346 - val_loss: 1.1799 - val_accuracy: 0.7205
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1775 - accuracy: 0.7387 - val_loss: 1.1783 - val_accuracy: 0.7216
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1758 - accuracy: 0.7367 - val_loss: 1.1767 - val_accuracy: 0.7224
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1741 - accuracy: 0.7364 - val_loss: 1.1748 - val_accuracy: 0.7336
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1724 - accuracy: 0.7376 - val_loss: 1.1732 - val_accuracy: 0.7209
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1706 - accuracy: 0.7432 - val_loss: 1.1711 - val_accuracy: 0.7243
# Epoch 105/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1689 - accuracy: 0.7358 - val_loss: 1.1697 - val_accuracy: 0.7179
# Epoch 106/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1672 - accuracy: 0.7341 - val_loss: 1.1678 - val_accuracy: 0.7306
# Epoch 107/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1655 - accuracy: 0.7404 - val_loss: 1.1661 - val_accuracy: 0.7291
# Epoch 108/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1637 - accuracy: 0.7454 - val_loss: 1.1643 - val_accuracy: 0.7168
# Epoch 109/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1620 - accuracy: 0.7367 - val_loss: 1.1630 - val_accuracy: 0.7239
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1603 - accuracy: 0.7407 - val_loss: 1.1611 - val_accuracy: 0.7213
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1586 - accuracy: 0.7439 - val_loss: 1.1596 - val_accuracy: 0.7134
# Epoch 112/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1569 - accuracy: 0.7358 - val_loss: 1.1577 - val_accuracy: 0.7243
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1553 - accuracy: 0.7407 - val_loss: 1.1562 - val_accuracy: 0.7231
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1536 - accuracy: 0.7386 - val_loss: 1.1545 - val_accuracy: 0.7205
# Epoch 115/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1519 - accuracy: 0.7363 - val_loss: 1.1527 - val_accuracy: 0.7254
# Epoch 116/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1502 - accuracy: 0.7442 - val_loss: 1.1511 - val_accuracy: 0.7220
# Epoch 117/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1486 - accuracy: 0.7381 - val_loss: 1.1494 - val_accuracy: 0.7272
# Epoch 118/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1469 - accuracy: 0.7438 - val_loss: 1.1479 - val_accuracy: 0.7205
# Epoch 119/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1453 - accuracy: 0.7382 - val_loss: 1.1462 - val_accuracy: 0.7220
# Epoch 120/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1436 - accuracy: 0.7418 - val_loss: 1.1445 - val_accuracy: 0.7231
# Epoch 121/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1420 - accuracy: 0.7360 - val_loss: 1.1428 - val_accuracy: 0.7295
# Epoch 122/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1403 - accuracy: 0.7430 - val_loss: 1.1415 - val_accuracy: 0.7336
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1387 - accuracy: 0.7487 - val_loss: 1.1398 - val_accuracy: 0.7224
# Epoch 124/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1371 - accuracy: 0.7376 - val_loss: 1.1382 - val_accuracy: 0.7254
# Epoch 125/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1355 - accuracy: 0.7432 - val_loss: 1.1365 - val_accuracy: 0.7280
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1339 - accuracy: 0.7428 - val_loss: 1.1352 - val_accuracy: 0.7220
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1323 - accuracy: 0.7444 - val_loss: 1.1336 - val_accuracy: 0.7254
# Epoch 128/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1307 - accuracy: 0.7406 - val_loss: 1.1321 - val_accuracy: 0.7250
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1292 - accuracy: 0.7473 - val_loss: 1.1302 - val_accuracy: 0.7243
# Epoch 130/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1276 - accuracy: 0.7442 - val_loss: 1.1289 - val_accuracy: 0.7157
# Epoch 131/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1260 - accuracy: 0.7379 - val_loss: 1.1274 - val_accuracy: 0.7302
# Epoch 132/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1244 - accuracy: 0.7457 - val_loss: 1.1255 - val_accuracy: 0.7187
# Epoch 133/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1229 - accuracy: 0.7403 - val_loss: 1.1241 - val_accuracy: 0.7265
# Epoch 134/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1214 - accuracy: 0.7451 - val_loss: 1.1226 - val_accuracy: 0.7269
# Epoch 135/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1198 - accuracy: 0.7439 - val_loss: 1.1211 - val_accuracy: 0.7265
# Epoch 136/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1183 - accuracy: 0.7442 - val_loss: 1.1196 - val_accuracy: 0.7254
# Epoch 137/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1167 - accuracy: 0.7442 - val_loss: 1.1178 - val_accuracy: 0.7280
# Epoch 138/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1152 - accuracy: 0.7477 - val_loss: 1.1167 - val_accuracy: 0.7287
# Epoch 139/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1137 - accuracy: 0.7435 - val_loss: 1.1151 - val_accuracy: 0.7284
# Epoch 140/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1122 - accuracy: 0.7473 - val_loss: 1.1137 - val_accuracy: 0.7246
# Epoch 141/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1106 - accuracy: 0.7400 - val_loss: 1.1119 - val_accuracy: 0.7336
# Epoch 142/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1092 - accuracy: 0.7473 - val_loss: 1.1106 - val_accuracy: 0.7313
# Epoch 143/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1076 - accuracy: 0.7544 - val_loss: 1.1092 - val_accuracy: 0.7183
# Epoch 144/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1061 - accuracy: 0.7371 - val_loss: 1.1078 - val_accuracy: 0.7325
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1047 - accuracy: 0.7458 - val_loss: 1.1061 - val_accuracy: 0.7336
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1033 - accuracy: 0.7498 - val_loss: 1.1046 - val_accuracy: 0.7276
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1018 - accuracy: 0.7491 - val_loss: 1.1029 - val_accuracy: 0.7299
# Epoch 148/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1003 - accuracy: 0.7408 - val_loss: 1.1017 - val_accuracy: 0.7284
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0988 - accuracy: 0.7494 - val_loss: 1.1007 - val_accuracy: 0.7265
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0974 - accuracy: 0.7478 - val_loss: 1.0990 - val_accuracy: 0.7299
# 413/413 [==============================] - 1s 1ms/step - loss: 1.0954 - accuracy: 0.7500
#  10%|████▎                                      | 1/10 [04:40<42:03, 280.35s/it]
# [1.0954015254974365, 0.75]
# 1.0 0.0
# (40000, 1000)
# Epoch 1/150
# 189/189 [==============================] - 1s 2ms/step - loss: 1.3862 - accuracy: 0.2533 - val_loss: 1.3863 - val_accuracy: 0.3575
# Epoch 2/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3857 - accuracy: 0.2651 - val_loss: 1.3857 - val_accuracy: 0.3571
# Epoch 3/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3852 - accuracy: 0.2734 - val_loss: 1.3853 - val_accuracy: 0.2425
# Epoch 4/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3848 - accuracy: 0.2938 - val_loss: 1.3850 - val_accuracy: 0.2425
# Epoch 5/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3844 - accuracy: 0.2845 - val_loss: 1.3846 - val_accuracy: 0.3086
# Epoch 6/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3839 - accuracy: 0.2992 - val_loss: 1.3837 - val_accuracy: 0.4175
# Epoch 7/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3835 - accuracy: 0.3417 - val_loss: 1.3831 - val_accuracy: 0.3067
# Epoch 8/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3830 - accuracy: 0.3762 - val_loss: 1.3833 - val_accuracy: 0.3929
# Epoch 9/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3825 - accuracy: 0.3155 - val_loss: 1.3828 - val_accuracy: 0.2754
# Epoch 10/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3821 - accuracy: 0.3515 - val_loss: 1.3819 - val_accuracy: 0.4325
# Epoch 11/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3817 - accuracy: 0.3948 - val_loss: 1.3817 - val_accuracy: 0.4235
# Epoch 12/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3812 - accuracy: 0.3800 - val_loss: 1.3812 - val_accuracy: 0.3739
# Epoch 13/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3807 - accuracy: 0.3915 - val_loss: 1.3807 - val_accuracy: 0.3899
# Epoch 14/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3803 - accuracy: 0.3853 - val_loss: 1.3803 - val_accuracy: 0.3198
# Epoch 15/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3798 - accuracy: 0.3161 - val_loss: 1.3799 - val_accuracy: 0.2381
# Epoch 16/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3794 - accuracy: 0.3549 - val_loss: 1.3794 - val_accuracy: 0.3515
# Epoch 17/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3790 - accuracy: 0.3570 - val_loss: 1.3788 - val_accuracy: 0.4366
# Epoch 18/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3785 - accuracy: 0.3814 - val_loss: 1.3787 - val_accuracy: 0.3522
# Epoch 19/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3781 - accuracy: 0.3611 - val_loss: 1.3781 - val_accuracy: 0.4112
# Epoch 20/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3776 - accuracy: 0.4648 - val_loss: 1.3779 - val_accuracy: 0.3425
# Epoch 21/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3772 - accuracy: 0.4035 - val_loss: 1.3771 - val_accuracy: 0.4090
# Epoch 22/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3767 - accuracy: 0.4193 - val_loss: 1.3765 - val_accuracy: 0.5728
# Epoch 23/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3763 - accuracy: 0.3805 - val_loss: 1.3761 - val_accuracy: 0.3769
# Epoch 24/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3759 - accuracy: 0.4128 - val_loss: 1.3756 - val_accuracy: 0.4728
# Epoch 25/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3754 - accuracy: 0.4689 - val_loss: 1.3750 - val_accuracy: 0.7340
# Epoch 26/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3749 - accuracy: 0.4680 - val_loss: 1.3749 - val_accuracy: 0.4190
# Epoch 27/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3745 - accuracy: 0.4753 - val_loss: 1.3746 - val_accuracy: 0.3825
# Epoch 28/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3740 - accuracy: 0.5038 - val_loss: 1.3741 - val_accuracy: 0.3799
# Epoch 29/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3736 - accuracy: 0.4391 - val_loss: 1.3736 - val_accuracy: 0.5418
# Epoch 30/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3731 - accuracy: 0.4597 - val_loss: 1.3725 - val_accuracy: 0.5784
# Epoch 31/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3727 - accuracy: 0.5751 - val_loss: 1.3725 - val_accuracy: 0.4549
# Epoch 32/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3722 - accuracy: 0.5113 - val_loss: 1.3721 - val_accuracy: 0.4157
# Epoch 33/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3718 - accuracy: 0.4543 - val_loss: 1.3717 - val_accuracy: 0.3765
# Epoch 34/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3714 - accuracy: 0.4745 - val_loss: 1.3711 - val_accuracy: 0.5261
# Epoch 35/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3708 - accuracy: 0.4731 - val_loss: 1.3710 - val_accuracy: 0.3549
# Epoch 36/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3705 - accuracy: 0.4810 - val_loss: 1.3703 - val_accuracy: 0.4966
# Epoch 37/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3700 - accuracy: 0.5066 - val_loss: 1.3699 - val_accuracy: 0.4224
# Epoch 38/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3696 - accuracy: 0.4782 - val_loss: 1.3696 - val_accuracy: 0.4545
# Epoch 39/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3691 - accuracy: 0.5190 - val_loss: 1.3690 - val_accuracy: 0.4660
# Epoch 40/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3687 - accuracy: 0.5589 - val_loss: 1.3685 - val_accuracy: 0.5160
# Epoch 41/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3683 - accuracy: 0.5120 - val_loss: 1.3680 - val_accuracy: 0.5765
# Epoch 42/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3678 - accuracy: 0.5440 - val_loss: 1.3676 - val_accuracy: 0.4948
# Epoch 43/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3673 - accuracy: 0.5440 - val_loss: 1.3671 - val_accuracy: 0.5899
# Epoch 44/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3669 - accuracy: 0.4913 - val_loss: 1.3665 - val_accuracy: 0.6993
# Epoch 45/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3665 - accuracy: 0.5979 - val_loss: 1.3663 - val_accuracy: 0.5642
# Epoch 46/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3660 - accuracy: 0.5967 - val_loss: 1.3660 - val_accuracy: 0.4571
# Epoch 47/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3656 - accuracy: 0.5544 - val_loss: 1.3653 - val_accuracy: 0.5489
# Epoch 48/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3652 - accuracy: 0.5582 - val_loss: 1.3651 - val_accuracy: 0.4601
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3647 - accuracy: 0.5425 - val_loss: 1.3648 - val_accuracy: 0.4526
# Epoch 50/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3643 - accuracy: 0.4846 - val_loss: 1.3641 - val_accuracy: 0.5534
# Epoch 51/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3638 - accuracy: 0.5898 - val_loss: 1.3635 - val_accuracy: 0.6172
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3634 - accuracy: 0.5748 - val_loss: 1.3631 - val_accuracy: 0.5608
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3629 - accuracy: 0.6365 - val_loss: 1.3629 - val_accuracy: 0.4866
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3625 - accuracy: 0.4887 - val_loss: 1.3620 - val_accuracy: 0.7004
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3621 - accuracy: 0.6068 - val_loss: 1.3616 - val_accuracy: 0.7138
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3616 - accuracy: 0.5437 - val_loss: 1.3611 - val_accuracy: 0.7153
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3612 - accuracy: 0.6369 - val_loss: 1.3610 - val_accuracy: 0.5440
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3607 - accuracy: 0.5731 - val_loss: 1.3605 - val_accuracy: 0.5743
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3603 - accuracy: 0.6117 - val_loss: 1.3602 - val_accuracy: 0.5269
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3599 - accuracy: 0.6076 - val_loss: 1.3598 - val_accuracy: 0.5034
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3594 - accuracy: 0.5920 - val_loss: 1.3594 - val_accuracy: 0.4698
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3590 - accuracy: 0.5639 - val_loss: 1.3587 - val_accuracy: 0.5597
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3586 - accuracy: 0.5815 - val_loss: 1.3581 - val_accuracy: 0.7090
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3581 - accuracy: 0.6678 - val_loss: 1.3578 - val_accuracy: 0.6034
# Epoch 65/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3577 - accuracy: 0.5532 - val_loss: 1.3573 - val_accuracy: 0.6362
# Epoch 66/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3572 - accuracy: 0.6212 - val_loss: 1.3567 - val_accuracy: 0.6836
# Epoch 67/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3568 - accuracy: 0.6318 - val_loss: 1.3562 - val_accuracy: 0.7291
# Epoch 68/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3563 - accuracy: 0.6846 - val_loss: 1.3564 - val_accuracy: 0.5291
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3559 - accuracy: 0.5276 - val_loss: 1.3553 - val_accuracy: 0.7134
# Epoch 70/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3555 - accuracy: 0.6429 - val_loss: 1.3550 - val_accuracy: 0.6862
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3551 - accuracy: 0.6204 - val_loss: 1.3547 - val_accuracy: 0.6071
# Epoch 72/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3546 - accuracy: 0.6155 - val_loss: 1.3542 - val_accuracy: 0.6388
# Epoch 73/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3542 - accuracy: 0.6583 - val_loss: 1.3537 - val_accuracy: 0.6705
# Epoch 74/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3538 - accuracy: 0.6491 - val_loss: 1.3537 - val_accuracy: 0.5149
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3533 - accuracy: 0.6075 - val_loss: 1.3529 - val_accuracy: 0.6672
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3529 - accuracy: 0.6430 - val_loss: 1.3527 - val_accuracy: 0.5903
# Epoch 77/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3525 - accuracy: 0.5809 - val_loss: 1.3520 - val_accuracy: 0.6836
# Epoch 78/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3520 - accuracy: 0.7520 - val_loss: 1.3517 - val_accuracy: 0.6108
# Epoch 79/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3517 - accuracy: 0.5907 - val_loss: 1.3512 - val_accuracy: 0.6216
# Epoch 80/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3512 - accuracy: 0.6209 - val_loss: 1.3506 - val_accuracy: 0.7022
# Epoch 81/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3507 - accuracy: 0.6034 - val_loss: 1.3501 - val_accuracy: 0.7429
# Epoch 82/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3504 - accuracy: 0.7316 - val_loss: 1.3499 - val_accuracy: 0.6332
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3499 - accuracy: 0.6262 - val_loss: 1.3494 - val_accuracy: 0.6683
# Epoch 84/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3495 - accuracy: 0.6653 - val_loss: 1.3493 - val_accuracy: 0.5433
# Epoch 85/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3490 - accuracy: 0.6400 - val_loss: 1.3489 - val_accuracy: 0.5854
# Epoch 86/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3486 - accuracy: 0.6494 - val_loss: 1.3481 - val_accuracy: 0.6631
# Epoch 87/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3482 - accuracy: 0.6540 - val_loss: 1.3477 - val_accuracy: 0.6511
# Epoch 88/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3477 - accuracy: 0.6988 - val_loss: 1.3476 - val_accuracy: 0.5836
# Epoch 89/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3473 - accuracy: 0.6707 - val_loss: 1.3470 - val_accuracy: 0.6093
# Epoch 90/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3469 - accuracy: 0.6455 - val_loss: 1.3468 - val_accuracy: 0.5840
# Epoch 91/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3465 - accuracy: 0.6674 - val_loss: 1.3458 - val_accuracy: 0.7108
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3460 - accuracy: 0.6322 - val_loss: 1.3453 - val_accuracy: 0.7437
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3456 - accuracy: 0.7245 - val_loss: 1.3455 - val_accuracy: 0.5336
# Epoch 94/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3452 - accuracy: 0.6064 - val_loss: 1.3445 - val_accuracy: 0.6996
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3448 - accuracy: 0.6678 - val_loss: 1.3441 - val_accuracy: 0.7082
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3444 - accuracy: 0.6861 - val_loss: 1.3439 - val_accuracy: 0.6448
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3439 - accuracy: 0.6689 - val_loss: 1.3432 - val_accuracy: 0.7224
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3435 - accuracy: 0.6698 - val_loss: 1.3428 - val_accuracy: 0.7224
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3431 - accuracy: 0.6491 - val_loss: 1.3422 - val_accuracy: 0.7716
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3427 - accuracy: 0.7450 - val_loss: 1.3421 - val_accuracy: 0.6649
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3422 - accuracy: 0.6665 - val_loss: 1.3417 - val_accuracy: 0.6832
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3418 - accuracy: 0.6726 - val_loss: 1.3411 - val_accuracy: 0.7280
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3414 - accuracy: 0.7065 - val_loss: 1.3410 - val_accuracy: 0.6399
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3409 - accuracy: 0.6646 - val_loss: 1.3404 - val_accuracy: 0.7131
# Epoch 105/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3406 - accuracy: 0.6790 - val_loss: 1.3399 - val_accuracy: 0.7228
# Epoch 106/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3401 - accuracy: 0.7145 - val_loss: 1.3395 - val_accuracy: 0.6806
# Epoch 107/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3397 - accuracy: 0.6529 - val_loss: 1.3389 - val_accuracy: 0.7451
# Epoch 108/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3393 - accuracy: 0.7037 - val_loss: 1.3386 - val_accuracy: 0.6888
# Epoch 109/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3388 - accuracy: 0.7036 - val_loss: 1.3384 - val_accuracy: 0.6325
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3384 - accuracy: 0.6393 - val_loss: 1.3375 - val_accuracy: 0.7612
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3380 - accuracy: 0.7130 - val_loss: 1.3373 - val_accuracy: 0.7007
# Epoch 112/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3376 - accuracy: 0.6937 - val_loss: 1.3368 - val_accuracy: 0.7429
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3371 - accuracy: 0.7010 - val_loss: 1.3366 - val_accuracy: 0.6970
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3368 - accuracy: 0.6925 - val_loss: 1.3360 - val_accuracy: 0.7116
# Epoch 115/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3363 - accuracy: 0.7020 - val_loss: 1.3358 - val_accuracy: 0.6586
# Epoch 116/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3359 - accuracy: 0.6608 - val_loss: 1.3352 - val_accuracy: 0.7224
# Epoch 117/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3354 - accuracy: 0.7405 - val_loss: 1.3351 - val_accuracy: 0.6123
# Epoch 118/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3350 - accuracy: 0.6709 - val_loss: 1.3345 - val_accuracy: 0.6996
# Epoch 119/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3346 - accuracy: 0.6830 - val_loss: 1.3338 - val_accuracy: 0.7485
# Epoch 120/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3342 - accuracy: 0.6678 - val_loss: 1.3333 - val_accuracy: 0.7530
# Epoch 121/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3338 - accuracy: 0.7428 - val_loss: 1.3331 - val_accuracy: 0.6795
# Epoch 122/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3334 - accuracy: 0.7305 - val_loss: 1.3328 - val_accuracy: 0.6552
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3329 - accuracy: 0.6569 - val_loss: 1.3320 - val_accuracy: 0.7884
# Epoch 124/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3325 - accuracy: 0.7386 - val_loss: 1.3319 - val_accuracy: 0.6780
# Epoch 125/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3321 - accuracy: 0.7112 - val_loss: 1.3315 - val_accuracy: 0.6974
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3317 - accuracy: 0.6603 - val_loss: 1.3306 - val_accuracy: 0.8007
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3313 - accuracy: 0.7456 - val_loss: 1.3306 - val_accuracy: 0.7104
# Epoch 128/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3309 - accuracy: 0.6881 - val_loss: 1.3298 - val_accuracy: 0.7507
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3305 - accuracy: 0.7479 - val_loss: 1.3301 - val_accuracy: 0.6164
# Epoch 130/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3300 - accuracy: 0.6545 - val_loss: 1.3290 - val_accuracy: 0.7743
# Epoch 131/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3296 - accuracy: 0.7291 - val_loss: 1.3287 - val_accuracy: 0.7675
# Epoch 132/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3292 - accuracy: 0.7445 - val_loss: 1.3285 - val_accuracy: 0.6981
# Epoch 133/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3288 - accuracy: 0.6899 - val_loss: 1.3278 - val_accuracy: 0.7668
# Epoch 134/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3283 - accuracy: 0.7503 - val_loss: 1.3278 - val_accuracy: 0.6694
# Epoch 135/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3279 - accuracy: 0.7240 - val_loss: 1.3275 - val_accuracy: 0.6522
# Epoch 136/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3276 - accuracy: 0.6661 - val_loss: 1.3267 - val_accuracy: 0.7075
# Epoch 137/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3271 - accuracy: 0.7296 - val_loss: 1.3263 - val_accuracy: 0.7015
# Epoch 138/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3267 - accuracy: 0.6927 - val_loss: 1.3259 - val_accuracy: 0.7093
# Epoch 139/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3262 - accuracy: 0.7481 - val_loss: 1.3257 - val_accuracy: 0.6959
# Epoch 140/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3259 - accuracy: 0.7435 - val_loss: 1.3252 - val_accuracy: 0.6959
# Epoch 141/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3254 - accuracy: 0.6997 - val_loss: 1.3247 - val_accuracy: 0.6929
# Epoch 142/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3250 - accuracy: 0.7128 - val_loss: 1.3243 - val_accuracy: 0.6899
# Epoch 143/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3246 - accuracy: 0.7034 - val_loss: 1.3236 - val_accuracy: 0.7451
# Epoch 144/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3242 - accuracy: 0.7385 - val_loss: 1.3232 - val_accuracy: 0.7444
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3238 - accuracy: 0.7211 - val_loss: 1.3227 - val_accuracy: 0.7683
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3233 - accuracy: 0.7375 - val_loss: 1.3225 - val_accuracy: 0.7351
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3229 - accuracy: 0.7165 - val_loss: 1.3218 - val_accuracy: 0.7959
# Epoch 148/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3225 - accuracy: 0.7631 - val_loss: 1.3217 - val_accuracy: 0.7183
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3220 - accuracy: 0.6844 - val_loss: 1.3211 - val_accuracy: 0.7716
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.3217 - accuracy: 0.7589 - val_loss: 1.3209 - val_accuracy: 0.7216
# 413/413 [==============================] - 1s 1ms/step - loss: 1.3213 - accuracy: 0.7222
#  20%|████████▌                                  | 2/10 [09:12<36:43, 275.49s/it]
# [1.3213250637054443, 0.7221969962120056]
# 1.0 0.0
# (40000, 1000)
# Epoch 1/150
# ...
# Epoch 42/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2608 - accuracy: 0.7300 - val_loss: 1.2603 - val_accuracy: 0.7284
# Epoch 43/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2581 - accuracy: 0.7325 - val_loss: 1.2579 - val_accuracy: 0.7321
# Epoch 44/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2554 - accuracy: 0.7371 - val_loss: 1.2552 - val_accuracy: 0.7261
# Epoch 45/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2527 - accuracy: 0.7477 - val_loss: 1.2523 - val_accuracy: 0.7310
# Epoch 46/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2500 - accuracy: 0.7296 - val_loss: 1.2496 - val_accuracy: 0.7481
# Epoch 47/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2474 - accuracy: 0.7585 - val_loss: 1.2473 - val_accuracy: 0.7160
# Epoch 48/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2447 - accuracy: 0.7222 - val_loss: 1.2445 - val_accuracy: 0.7422
# Epoch 49/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2420 - accuracy: 0.7561 - val_loss: 1.2418 - val_accuracy: 0.7082
# Epoch 50/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2394 - accuracy: 0.7248 - val_loss: 1.2389 - val_accuracy: 0.7351
# Epoch 51/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2368 - accuracy: 0.7525 - val_loss: 1.2365 - val_accuracy: 0.7209
# Epoch 52/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2342 - accuracy: 0.7303 - val_loss: 1.2340 - val_accuracy: 0.7347
# Epoch 53/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2316 - accuracy: 0.7556 - val_loss: 1.2314 - val_accuracy: 0.7198
# Epoch 54/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2291 - accuracy: 0.7302 - val_loss: 1.2286 - val_accuracy: 0.7299
# Epoch 55/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2265 - accuracy: 0.7389 - val_loss: 1.2266 - val_accuracy: 0.7358
# Epoch 56/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2240 - accuracy: 0.7415 - val_loss: 1.2240 - val_accuracy: 0.7257
# Epoch 57/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2215 - accuracy: 0.7402 - val_loss: 1.2211 - val_accuracy: 0.7384
# Epoch 58/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2190 - accuracy: 0.7477 - val_loss: 1.2190 - val_accuracy: 0.7220
# Epoch 59/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2164 - accuracy: 0.7336 - val_loss: 1.2161 - val_accuracy: 0.7433
# Epoch 60/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2140 - accuracy: 0.7414 - val_loss: 1.2137 - val_accuracy: 0.7299
# Epoch 61/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2115 - accuracy: 0.7434 - val_loss: 1.2113 - val_accuracy: 0.7463
# Epoch 62/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2091 - accuracy: 0.7376 - val_loss: 1.2088 - val_accuracy: 0.7422
# Epoch 63/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2066 - accuracy: 0.7351 - val_loss: 1.2069 - val_accuracy: 0.7455
# Epoch 64/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2042 - accuracy: 0.7456 - val_loss: 1.2040 - val_accuracy: 0.7332
# Epoch 65/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.2018 - accuracy: 0.7529 - val_loss: 1.2017 - val_accuracy: 0.7306
# Epoch 66/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1993 - accuracy: 0.7368 - val_loss: 1.1993 - val_accuracy: 0.7433
# Epoch 67/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1970 - accuracy: 0.7472 - val_loss: 1.1967 - val_accuracy: 0.7377
# Epoch 68/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1945 - accuracy: 0.7445 - val_loss: 1.1949 - val_accuracy: 0.7291
# Epoch 69/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1922 - accuracy: 0.7436 - val_loss: 1.1923 - val_accuracy: 0.7384
# Epoch 70/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1898 - accuracy: 0.7461 - val_loss: 1.1898 - val_accuracy: 0.7310
# Epoch 71/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1874 - accuracy: 0.7490 - val_loss: 1.1875 - val_accuracy: 0.7295
# Epoch 72/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1850 - accuracy: 0.7383 - val_loss: 1.1849 - val_accuracy: 0.7437
# Epoch 73/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1827 - accuracy: 0.7488 - val_loss: 1.1824 - val_accuracy: 0.7418
# Epoch 74/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1803 - accuracy: 0.7517 - val_loss: 1.1804 - val_accuracy: 0.7276
# Epoch 75/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1779 - accuracy: 0.7439 - val_loss: 1.1777 - val_accuracy: 0.7328
# Epoch 76/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1756 - accuracy: 0.7410 - val_loss: 1.1756 - val_accuracy: 0.7504
# Epoch 77/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1733 - accuracy: 0.7502 - val_loss: 1.1734 - val_accuracy: 0.7466
# Epoch 78/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1710 - accuracy: 0.7504 - val_loss: 1.1714 - val_accuracy: 0.7396
# Epoch 79/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1687 - accuracy: 0.7476 - val_loss: 1.1691 - val_accuracy: 0.7403
# Epoch 80/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1663 - accuracy: 0.7508 - val_loss: 1.1661 - val_accuracy: 0.7377
# Epoch 81/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1641 - accuracy: 0.7453 - val_loss: 1.1640 - val_accuracy: 0.7366
# Epoch 82/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1618 - accuracy: 0.7522 - val_loss: 1.1618 - val_accuracy: 0.7358
# Epoch 83/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1595 - accuracy: 0.7420 - val_loss: 1.1598 - val_accuracy: 0.7437
# Epoch 84/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1572 - accuracy: 0.7515 - val_loss: 1.1576 - val_accuracy: 0.7422
# Epoch 85/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1550 - accuracy: 0.7508 - val_loss: 1.1550 - val_accuracy: 0.7373
# Epoch 86/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1528 - accuracy: 0.7527 - val_loss: 1.1528 - val_accuracy: 0.7373
# Epoch 87/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1505 - accuracy: 0.7536 - val_loss: 1.1507 - val_accuracy: 0.7313
# Epoch 88/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1483 - accuracy: 0.7473 - val_loss: 1.1487 - val_accuracy: 0.7231
# Epoch 89/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1461 - accuracy: 0.7411 - val_loss: 1.1464 - val_accuracy: 0.7437
# Epoch 90/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1439 - accuracy: 0.7572 - val_loss: 1.1442 - val_accuracy: 0.7291
# Epoch 91/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1418 - accuracy: 0.7485 - val_loss: 1.1417 - val_accuracy: 0.7366
# Epoch 92/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1395 - accuracy: 0.7411 - val_loss: 1.1402 - val_accuracy: 0.7470
# Epoch 93/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1375 - accuracy: 0.7591 - val_loss: 1.1377 - val_accuracy: 0.7377
# Epoch 94/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1353 - accuracy: 0.7466 - val_loss: 1.1358 - val_accuracy: 0.7478
# Epoch 95/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1332 - accuracy: 0.7510 - val_loss: 1.1336 - val_accuracy: 0.7478
# Epoch 96/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1310 - accuracy: 0.7527 - val_loss: 1.1312 - val_accuracy: 0.7519
# Epoch 97/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1289 - accuracy: 0.7656 - val_loss: 1.1296 - val_accuracy: 0.7332
# Epoch 98/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1269 - accuracy: 0.7520 - val_loss: 1.1277 - val_accuracy: 0.7381
# Epoch 99/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1248 - accuracy: 0.7483 - val_loss: 1.1253 - val_accuracy: 0.7448
# Epoch 100/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1227 - accuracy: 0.7571 - val_loss: 1.1230 - val_accuracy: 0.7362
# Epoch 101/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1206 - accuracy: 0.7513 - val_loss: 1.1211 - val_accuracy: 0.7433
# Epoch 102/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1186 - accuracy: 0.7543 - val_loss: 1.1195 - val_accuracy: 0.7410
# Epoch 103/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1166 - accuracy: 0.7551 - val_loss: 1.1172 - val_accuracy: 0.7496
# Epoch 104/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1146 - accuracy: 0.7541 - val_loss: 1.1151 - val_accuracy: 0.7511
# Epoch 105/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1126 - accuracy: 0.7557 - val_loss: 1.1132 - val_accuracy: 0.7474
# Epoch 106/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1105 - accuracy: 0.7597 - val_loss: 1.1112 - val_accuracy: 0.7474
# Epoch 107/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1085 - accuracy: 0.7573 - val_loss: 1.1089 - val_accuracy: 0.7466
# Epoch 108/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1066 - accuracy: 0.7550 - val_loss: 1.1070 - val_accuracy: 0.7496
# Epoch 109/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1046 - accuracy: 0.7578 - val_loss: 1.1053 - val_accuracy: 0.7478
# Epoch 110/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1026 - accuracy: 0.7628 - val_loss: 1.1030 - val_accuracy: 0.7347
# Epoch 111/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.1006 - accuracy: 0.7595 - val_loss: 1.1015 - val_accuracy: 0.7418
# Epoch 112/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0986 - accuracy: 0.7588 - val_loss: 1.0992 - val_accuracy: 0.7470
# Epoch 113/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0967 - accuracy: 0.7567 - val_loss: 1.0972 - val_accuracy: 0.7485
# Epoch 114/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0947 - accuracy: 0.7569 - val_loss: 1.0953 - val_accuracy: 0.7504
# Epoch 115/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0928 - accuracy: 0.7605 - val_loss: 1.0934 - val_accuracy: 0.7481
# Epoch 116/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0908 - accuracy: 0.7609 - val_loss: 1.0914 - val_accuracy: 0.7489
# Epoch 117/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0889 - accuracy: 0.7575 - val_loss: 1.0894 - val_accuracy: 0.7537
# Epoch 118/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0870 - accuracy: 0.7673 - val_loss: 1.0878 - val_accuracy: 0.7500
# Epoch 119/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0851 - accuracy: 0.7573 - val_loss: 1.0858 - val_accuracy: 0.7522
# Epoch 120/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0832 - accuracy: 0.7636 - val_loss: 1.0840 - val_accuracy: 0.7493
# Epoch 121/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0813 - accuracy: 0.7544 - val_loss: 1.0822 - val_accuracy: 0.7627
# Epoch 122/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0794 - accuracy: 0.7706 - val_loss: 1.0805 - val_accuracy: 0.7474
# Epoch 123/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0775 - accuracy: 0.7588 - val_loss: 1.0785 - val_accuracy: 0.7537
# Epoch 124/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0758 - accuracy: 0.7614 - val_loss: 1.0766 - val_accuracy: 0.7522
# Epoch 125/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0739 - accuracy: 0.7604 - val_loss: 1.0747 - val_accuracy: 0.7582
# Epoch 126/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0720 - accuracy: 0.7600 - val_loss: 1.0727 - val_accuracy: 0.7623
# Epoch 127/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0702 - accuracy: 0.7639 - val_loss: 1.0711 - val_accuracy: 0.7541
# Epoch 128/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0684 - accuracy: 0.7665 - val_loss: 1.0692 - val_accuracy: 0.7496
# Epoch 129/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0665 - accuracy: 0.7621 - val_loss: 1.0674 - val_accuracy: 0.7526
# Epoch 130/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0647 - accuracy: 0.7634 - val_loss: 1.0651 - val_accuracy: 0.7563
# Epoch 131/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0629 - accuracy: 0.7585 - val_loss: 1.0638 - val_accuracy: 0.7619
# Epoch 132/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0611 - accuracy: 0.7686 - val_loss: 1.0622 - val_accuracy: 0.7541
# Epoch 133/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0593 - accuracy: 0.7667 - val_loss: 1.0603 - val_accuracy: 0.7496
# Epoch 134/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0575 - accuracy: 0.7647 - val_loss: 1.0580 - val_accuracy: 0.7563
# Epoch 135/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0557 - accuracy: 0.7672 - val_loss: 1.0566 - val_accuracy: 0.7537
# Epoch 136/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0539 - accuracy: 0.7661 - val_loss: 1.0552 - val_accuracy: 0.7478
# Epoch 137/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0522 - accuracy: 0.7659 - val_loss: 1.0534 - val_accuracy: 0.7519
# Epoch 138/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0504 - accuracy: 0.7664 - val_loss: 1.0516 - val_accuracy: 0.7534
# Epoch 139/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0487 - accuracy: 0.7677 - val_loss: 1.0496 - val_accuracy: 0.7511
# Epoch 140/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0470 - accuracy: 0.7689 - val_loss: 1.0479 - val_accuracy: 0.7519
# Epoch 141/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0452 - accuracy: 0.7643 - val_loss: 1.0462 - val_accuracy: 0.7563
# Epoch 142/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0435 - accuracy: 0.7679 - val_loss: 1.0446 - val_accuracy: 0.7552
# Epoch 143/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0418 - accuracy: 0.7702 - val_loss: 1.0426 - val_accuracy: 0.7496
# Epoch 144/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0401 - accuracy: 0.7643 - val_loss: 1.0408 - val_accuracy: 0.7560
# Epoch 145/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0384 - accuracy: 0.7697 - val_loss: 1.0395 - val_accuracy: 0.7586
# Epoch 146/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0367 - accuracy: 0.7711 - val_loss: 1.0374 - val_accuracy: 0.7578
# Epoch 147/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0350 - accuracy: 0.7666 - val_loss: 1.0361 - val_accuracy: 0.7608
# Epoch 148/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0334 - accuracy: 0.7707 - val_loss: 1.0346 - val_accuracy: 0.7578
# Epoch 149/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0317 - accuracy: 0.7704 - val_loss: 1.0328 - val_accuracy: 0.7578
# Epoch 150/150
# 189/189 [==============================] - 0s 2ms/step - loss: 1.0301 - accuracy: 0.7703 - val_loss: 1.0311 - val_accuracy: 0.7590
# 413/413 [==============================] - 1s 1ms/step - loss: 1.0276 - accuracy: 0.7695
# 100%|██████████████████████████████████████████| 10/10 [46:38<00:00, 279.89s/it]
# [1.0276236534118652, 0.7695454359054565]

# %%
print(np.mean(total_scores))
print(np.std(total_scores))
# Out:
# 0.741689395904541
# 0.06987631938237779
